# %% [markdown]
# # Keyterm Parsing

# %%
import itertools
import networkx as nx
import nltk
import os
import numpy as np
import time
import json

import matplotlib.pyplot as plt
from nltk.corpus import words, gutenberg, reuters, webtext
import inflect
from nltk.corpus import wordnet as wn
import string

# %%
import spacy
from spacy.matcher import Matcher
from spacy.pipeline import EntityRuler
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

# %%
with open('../samples/sample.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
with open('../lib/plural_to_singular.json', 'r') as f:
    plural_to_singular = json.load(f)

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
from textrank_spacy import extract_top_terms

# %%
patterns = extract_top_terms(text, stopwords, plural_to_singular)
# Out:
# [('deep', 'learning'), ('numerical', 'value'), ('neural', 'network'), ('batch', 'size'), ('activation', 'function'), ('cross', '-'), ('-', 'entropy'), ('training', 'process'), ('learning', 'models'), ('example', 'below'), ('test', 'dataset'), ('entropy', 'loss'), ('separate', 'libraries'), ('next', 'value'), ('classification', 'accuracy'), ('training', 'dataset'), ('validation', 'dataset'), ('very', 'close'), ('validation', 'datasets'), ('lines', 'codes'), ('tf.keras', 'API'), ('line', 'plot'), ('accuracy', 'evaluation'), ('loss', 'function'), ('test', 'datasets'), ('classification', 'problem'), ('output', 'layer'), ('model.fit', 'data'), ('learning', 'library'), ('example', 'first'), ('when', 'training'), ('standard', 'deep'), ('learning', 'process'), ('nodes', 'where'), ('Keras', 'API'), ('execution', 'time'), ('image', 'classification'), ('deep', 'neural'), ('data', 'prior'), ('training', 'epoch'), ('project', 'now'), ('evaluation', 'process'), ('layer', 'prior'), ('more', 'epochs'), ('classification', 'tasks'), ('new', 'row'), ('use', 'batch'), ('next', 'class'), ('input', 'data'), ('%', 'validation'), ('learning', 'project'), ('e.g.', 'where'), ('input', 'layer'), ('%', 'class'), ('CNN', 'example'), ('%', 'test'), ('network', 'model'), ('same', 'image'), ('Keras', 'project'), ('new', 'data'), ('-', 'validation'), ('model', 'performance'), ('validation', 'data'), ('new', 'layer'), ('better', 'performance'), ('standard', 'models'), ('how', 'batch'), ('test', 'data'), ('epoch', 'loss'), ('error', 'loss'), ('loss', 'values'), ('model', 'evaluation'), ('TensorFlow', 'project'), ('same', 'input'), ('learning', 'tasks'), ('loss', 'line'), ('prediction', 'problem'), ('MLP', 'model'), ('classification', 'dataset'), ('next', 'layer'), ('classification', 'prediction'), ('CNN', 'models'), ('image', 'input'), ('%', 'training'), ('CNN', 'model'), ('first', 'image'), ('prior', 'layer'), ('MLP', 'network'), ('more', 'here'), ('learning', 'libraries'), ('very', 'deep'), ('%', 'accuracy'), ('-', 'batch'), ('data', 'code'), ('use', 'code'), ('e.g.', 'function'), ('training', 'images'), ('training', 'very'), ('tf.keras', 'new'), ('training', 'epochs'), ('code', 'example'), ('training', 'data'), ('output', 'layers'), ('new', 'function'), ('layer', 'when'), ('network', 'models'), ('test', 'loss'), ('learning', 'performance'), ('later', 'use'), ('image', 'data'), ('deep', 'MLP'), ('learning', 'model'), ('-', 'class'), ('output', 'function'), ('%', 'loss'), ('model', 'error'), ('TensorFlow', 'deep'), ('data', 'input'), ('model', 'API'), ('dataset', 'then'), ('model', 'when'), ('same', 'model'), ('training', 'deep'), ('model', 'later'), ('use', 'deep'), ('new', 'model'), ('-', 'layer'), ('model', 'more'), ('model', 'training'), ('layer', 'model')]

# %%
for pat in patterns:
    if pat['id'] == 'neural-network':
        print(pat)
# Out:
# {'label': 'CUSTOM', 'pattern': 'neural network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'neural networks', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'neural Network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'neural Networks', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'neurals network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'neurals networks', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'neurals Network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'neurals Networks', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neural network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neural networks', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neural Network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neural Networks', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neurals network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neurals networks', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neurals Network', 'id': 'neural-network'}
# {'label': 'CUSTOM', 'pattern': 'Neurals Networks', 'id': 'neural-network'}

# %% [markdown]
# ## Entity Rules

# %% [markdown]
# Acroynms are defined as uppercase words of length greater than 1.

# %%
matcher = Matcher(nlp.vocab)
# Add match ID "HelloWorld" with no callback and one pattern
pattern = [{"IS_UPPER": True}]
matcher.add("acronym", None, pattern)

doc = nlp(text)
matches = matcher(doc)
acroynm_candidates = []
acroynm_set = set([])
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    if len(span.text) > 1 and span.text not in acroynm_set:
        acroynm_candidates.append(span)
        acroynm_set.add(span.text)
#     print(match_id, string_id, start, end, span.text)

# %%
acroynm_candidates
# Out:
# [API,
#  CNTK,
#  GPU,
#  CPU,
#  IDE,
#  MLP,
#  MSE,
#  RMSE,
#  MNIST,
#  CNN,
#  RNN,
#  LSTM,
#  MAE,
#  H5,
#  TF,
#  GAN,
#  MUNIT,
#  BUT,
#  JG,
#  VGG16,
#  SGD,
#  PO,
#  ACN,
#  RSS]

# %%
def simplify(text):
    """Convert to lowercase, remove stopword, and singularize nouns"""
    tokens = nltk.word_tokenize(text.lower())
    simplified_tokens = []
    for word in tokens:
        if word not in stopwords and word not in string.punctuation:
            if word in plural_to_singular.keys():
                singular = plural_to_singular[word]
            else:
                singular = word
            simplified_tokens.append(singular)
    return simplified_tokens

def get_ent_id(text):
    return '-'.join(simplify(text))

# %%
entity_rules = []
entity_set = set([])
entity_ids = set([])
skiplabels = [ 'DATE','TIME', 'PERCENT', 'MONEY', 'QUANTITY','ORDINAL', 'CARDINAL']
i = 0
for ent in doc.ents:
    ent_id = get_ent_id(ent.text)
#     term = ent.text
    if ent.label_ not in skiplabels and ent.text not in entity_set:
        entity_rules.append((ent, ent_id))
        entity_set.add(ent.text)
        entity_ids.add(ent_id)

# %%
entity_rules
# Out:
# [(TensorFlow, 'tensorflow'),
#  (Google, 'google'),
#  (tf.keras API, 'tf.keras-api'),
#  (Keras, 'keras'),
#  (tf.keras, 'tf.keras'),
#  (the tf.keras API, 'tf.keras-api'),
#  (Stephen Harlan, 'stephen-harlan'),
#  (API, 'api'),
#  (python, 'python'),
#  (algorithm, 'algorithm'),
#  (Python, 'python'),
#  (PyTorch, 'pytorch'),
#  (Theano, 'theano'),
#  (CNTK, 'cntk'),
#  (TensorFlow 2, 'tensorflow-2'),
#  (Keras API, 'keras-api'),
#  (Keras Project Homepage, 'keras-project-homepage'),
#  (Anaconda, 'anaconda'),
#  (GPU, 'gpu'),
#  (IDE, 'ides'),
#  (the Sequential API, 'sequential-api'),
#  (the Functional API, 'functional-api'),
#  (Adam, 'adam'),
#  (Sequential, 'sequential'),
#  (MLP, 'mlp'),
#  (Input, 'input'),
#  (Model, 'model'),
#  (Multilayer Perceptrons, 'multilayer-perceptrons'),
#  (Convolutional Neural Networks, 'convolutional-neural-network'),
#  (Recurrent Neural Networks, 'recurrent-neural-network'),
#  (Multilayer Perceptron, 'multilayer-perceptron'),
#  (Ionosphere, 'ionosphere'),
#  (Pandas, 'pandas'),
#  (LabelEncoder, 'labelencoder'),
#  (ReLU, 'relu'),
#  (Iris, 'iris'),
#  (Boston, 'boston'),
#  (RMSE, 'rmse'),
#  (MNIST, 'mnist'),
#  (CNN, 'cnn'),
#  (RNN, 'rnn'),
#  (the Long Short-Term Memory, 'long-short-term-memory'),
#  (MAE, 'mae'),
#  (Neural Network Architecture Learning,
#   'neural-network-architecture-learning'),
#  (validation_split, 'validation_split'),
#  (Matplotlib, 'matplotlib'),
#  (val_loss, 'val_loss'),
#  (H5, 'h5'),
#  (h5py, 'h5py'),
#  (BatchNormalization, 'batchnormalization'),
#  (EarlyStopping, 'earlystopping'),
#  (Convolutional Nets, 'convolutional-net'),
#  (Markus, 'markus'),
#  (Jason, 'jason'),
#  (Relu, 'relu'),
#  (Sigmoid, 'sigmoid'),
#  (https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/,
#   'https-//machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/'),
#  (tf.nn., 'tf.nn'),
#  (MLP Binary Classification, 'mlp-binary-classification'),
#  (acc, 'acc'),
#  (MaxPool2D, 'maxpool2d'),
#  (https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D,
#   'https-//www.tensorflow.org/api_docs/python/tf/keras/layers/maxpool2d'),
#  (GAN, 'gan'),
#  (MUNIT, 'munit'),
#  (Mark Thanks, 'mark-thanks'),
#  (English, 'english'),
#  (Multiclassification, 'multiclassification'),
#  (JG Nice, 'jg-nice'),
#  (Hi Jason, 'hi-jason'),
#  (Validation, 'validation'),
#  (Objetive, 'objetive'),
#  (Conv2D, 'conv2d'),
#  (Data Augmentation, 'datum-augmentation'),
#  (reTrain, 'retrain'),
#  (ImageDataGenerator’, 'imagedatagenerator-’'),
#  (keras, 'keras'),
#  (Black/White, 'black/white'),
#  (np.stack, 'np.stack'),
#  (keras.io, 'keras.io'),
#  (MeanSquaredError, 'meansquarederror'),
#  (np, 'np'),
#  (y_t, 'y_t'),
#  (np.array([[1, 'np.array-1'),
#  (loss1, 'loss1'),
#  (Tensor(621, 'tensor-621'),
#  (shape=, 'shape='),
#  (dtype=, 'dtype='),
#  (np import keras, 'np-import-keras'),
#  (mse2(y_t, 'mse2-y_t'),
#  (fns, 'fns'),
#  (EBook, 'ebook'),
#  (All Rights Reserved, 'right-reserved'),
#  (PO Box 206, 'po-box-206'),
#  (Australia, 'australia'),
#  (LinkedIn, 'linkedin'),
#  (|
#
#    , ''),
#  (|
#
#    , ''),
#  (|
#
#    Search, 'search')]

# %%
ent_id_list = list(entity_ids)
acronym_pairs = {}
acronym_rules = []

for cand in acroynm_candidates:
    cand_lower = cand.text.lower()

    for ent_id in ent_id_list:
        tokens = ent_id.split('-')
        
        if len(cand_lower) == len(tokens):
            match = all([cand_lower[i] == tokens[i][0] for i in range(len(cand_lower))])
        else:
            match = False
        
        if match:
            acronym_pairs[cand_lower] = ent_id
            acronym_pairs[cand_lower + 's'] = ent_id
            
            acronym_rules.append((cand.text, ent_id))
            acronym_rules.append((cand.text + 's', ent_id))
            break

# %%
acronym_pairs
# Out:
# {'cnn': 'convolutional-neural-network',
#  'cnns': 'convolutional-neural-network',
#  'rnn': 'recurrent-neural-network',
#  'rnns': 'recurrent-neural-network',
#  'lstm': 'long-short-term-memory',
#  'lstms': 'long-short-term-memory'}

# %%
acronym_rules
# Out:
# [('CNN', 'convolutional-neural-network'),
#  ('CNNs', 'convolutional-neural-network'),
#  ('RNN', 'recurrent-neural-network'),
#  ('RNNs', 'recurrent-neural-network'),
#  ('LSTM', 'long-short-term-memory'),
#  ('LSTMs', 'long-short-term-memory')]

# %%
entity_patterns = []

for chunk, ent_id in entity_rules:
    if chunk[0].text in ['the', 'The']:
        pattern = chunk[1:].text
    else:
        pattern = chunk.text
    
    if ent_id in acronym_pairs.keys():
        pattern_id = acronym_pairs[ent_id]
    else:
        pattern_id = ent_id
        
    entity_patterns.append({'label':'CUSTOM', 'pattern':pattern, 'id':pattern_id})

# %%
for pattern, ent_id in acronym_rules:
    entity_patterns.append({'label':'CUSTOM', 'pattern':pattern, 'id':ent_id})

# %%
entity_patterns
# Out:
# [{'label': 'CUSTOM', 'pattern': 'TensorFlow', 'id': 'tensorflow'},
#  {'label': 'CUSTOM', 'pattern': 'Google', 'id': 'google'},
#  {'label': 'CUSTOM', 'pattern': 'tf.keras API', 'id': 'tf.keras-api'},
#  {'label': 'CUSTOM', 'pattern': 'Keras', 'id': 'keras'},
#  {'label': 'CUSTOM', 'pattern': 'tf.keras', 'id': 'tf.keras'},
#  {'label': 'CUSTOM', 'pattern': 'tf.keras API', 'id': 'tf.keras-api'},
#  {'label': 'CUSTOM', 'pattern': 'Stephen Harlan', 'id': 'stephen-harlan'},
#  {'label': 'CUSTOM', 'pattern': 'API', 'id': 'api'},
#  {'label': 'CUSTOM', 'pattern': 'python', 'id': 'python'},
#  {'label': 'CUSTOM', 'pattern': 'algorithm', 'id': 'algorithm'},
#  {'label': 'CUSTOM', 'pattern': 'Python', 'id': 'python'},
#  {'label': 'CUSTOM', 'pattern': 'PyTorch', 'id': 'pytorch'},
#  {'label': 'CUSTOM', 'pattern': 'Theano', 'id': 'theano'},
#  {'label': 'CUSTOM', 'pattern': 'CNTK', 'id': 'cntk'},
#  {'label': 'CUSTOM', 'pattern': 'TensorFlow 2', 'id': 'tensorflow-2'},
#  {'label': 'CUSTOM', 'pattern': 'Keras API', 'id': 'keras-api'},
#  {'label': 'CUSTOM',
#   'pattern': 'Keras Project Homepage',
#   'id': 'keras-project-homepage'},
#  {'label': 'CUSTOM', 'pattern': 'Anaconda', 'id': 'anaconda'},
#  {'label': 'CUSTOM', 'pattern': 'GPU', 'id': 'gpu'},
#  {'label': 'CUSTOM', 'pattern': 'IDE', 'id': 'ides'},
#  {'label': 'CUSTOM', 'pattern': 'Sequential API', 'id': 'sequential-api'},
#  {'label': 'CUSTOM', 'pattern': 'Functional API', 'id': 'functional-api'},
#  {'label': 'CUSTOM', 'pattern': 'Adam', 'id': 'adam'},
#  {'label': 'CUSTOM', 'pattern': 'Sequential', 'id': 'sequential'},
#  {'label': 'CUSTOM', 'pattern': 'MLP', 'id': 'mlp'},
#  {'label': 'CUSTOM', 'pattern': 'Input', 'id': 'input'},
#  {'label': 'CUSTOM', 'pattern': 'Model', 'id': 'model'},
#  {'label': 'CUSTOM',
#   'pattern': 'Multilayer Perceptrons',
#   'id': 'multilayer-perceptrons'},
#  {'label': 'CUSTOM',
#   'pattern': 'Convolutional Neural Networks',
#   'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM',
#   'pattern': 'Recurrent Neural Networks',
#   'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM',
#   'pattern': 'Multilayer Perceptron',
#   'id': 'multilayer-perceptron'},
#  {'label': 'CUSTOM', 'pattern': 'Ionosphere', 'id': 'ionosphere'},
#  {'label': 'CUSTOM', 'pattern': 'Pandas', 'id': 'pandas'},
#  {'label': 'CUSTOM', 'pattern': 'LabelEncoder', 'id': 'labelencoder'},
#  {'label': 'CUSTOM', 'pattern': 'ReLU', 'id': 'relu'},
#  {'label': 'CUSTOM', 'pattern': 'Iris', 'id': 'iris'},
#  {'label': 'CUSTOM', 'pattern': 'Boston', 'id': 'boston'},
#  {'label': 'CUSTOM', 'pattern': 'RMSE', 'id': 'rmse'},
#  {'label': 'CUSTOM', 'pattern': 'MNIST', 'id': 'mnist'},
#  {'label': 'CUSTOM', 'pattern': 'CNN', 'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'RNN', 'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM',
#   'pattern': 'Long Short-Term Memory',
#   'id': 'long-short-term-memory'},
#  {'label': 'CUSTOM', 'pattern': 'MAE', 'id': 'mae'},
#  {'label': 'CUSTOM',
#   'pattern': 'Neural Network Architecture Learning',
#   'id': 'neural-network-architecture-learning'},
#  {'label': 'CUSTOM', 'pattern': 'validation_split', 'id': 'validation_split'},
#  {'label': 'CUSTOM', 'pattern': 'Matplotlib', 'id': 'matplotlib'},
#  {'label': 'CUSTOM', 'pattern': 'val_loss', 'id': 'val_loss'},
#  {'label': 'CUSTOM', 'pattern': 'H5', 'id': 'h5'},
#  {'label': 'CUSTOM', 'pattern': 'h5py', 'id': 'h5py'},
#  {'label': 'CUSTOM',
#   'pattern': 'BatchNormalization',
#   'id': 'batchnormalization'},
#  {'label': 'CUSTOM', 'pattern': 'EarlyStopping', 'id': 'earlystopping'},
#  {'label': 'CUSTOM',
#   'pattern': 'Convolutional Nets',
#   'id': 'convolutional-net'},
#  {'label': 'CUSTOM', 'pattern': 'Markus', 'id': 'markus'},
#  {'label': 'CUSTOM', 'pattern': 'Jason', 'id': 'jason'},
#  {'label': 'CUSTOM', 'pattern': 'Relu', 'id': 'relu'},
#  {'label': 'CUSTOM', 'pattern': 'Sigmoid', 'id': 'sigmoid'},
#  {'label': 'CUSTOM',
#   'pattern': 'https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/',
#   'id': 'https-//machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/'},
#  {'label': 'CUSTOM', 'pattern': 'tf.nn.', 'id': 'tf.nn'},
#  {'label': 'CUSTOM',
#   'pattern': 'MLP Binary Classification',
#   'id': 'mlp-binary-classification'},
#  {'label': 'CUSTOM', 'pattern': 'acc', 'id': 'acc'},
#  {'label': 'CUSTOM', 'pattern': 'MaxPool2D', 'id': 'maxpool2d'},
#  {'label': 'CUSTOM',
#   'pattern': 'https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D',
#   'id': 'https-//www.tensorflow.org/api_docs/python/tf/keras/layers/maxpool2d'},
#  {'label': 'CUSTOM', 'pattern': 'GAN', 'id': 'gan'},
#  {'label': 'CUSTOM', 'pattern': 'MUNIT', 'id': 'munit'},
#  {'label': 'CUSTOM', 'pattern': 'Mark Thanks', 'id': 'mark-thanks'},
#  {'label': 'CUSTOM', 'pattern': 'English', 'id': 'english'},
#  {'label': 'CUSTOM',
#   'pattern': 'Multiclassification',
#   'id': 'multiclassification'},
#  {'label': 'CUSTOM', 'pattern': 'JG Nice', 'id': 'jg-nice'},
#  {'label': 'CUSTOM', 'pattern': 'Hi Jason', 'id': 'hi-jason'},
#  {'label': 'CUSTOM', 'pattern': 'Validation', 'id': 'validation'},
#  {'label': 'CUSTOM', 'pattern': 'Objetive', 'id': 'objetive'},
#  {'label': 'CUSTOM', 'pattern': 'Conv2D', 'id': 'conv2d'},
#  {'label': 'CUSTOM',
#   'pattern': 'Data Augmentation',
#   'id': 'datum-augmentation'},
#  {'label': 'CUSTOM', 'pattern': 'reTrain', 'id': 'retrain'},
#  {'label': 'CUSTOM',
#   'pattern': 'ImageDataGenerator’',
#   'id': 'imagedatagenerator-’'},
#  {'label': 'CUSTOM', 'pattern': 'keras', 'id': 'keras'},
#  {'label': 'CUSTOM', 'pattern': 'Black/White', 'id': 'black/white'},
#  {'label': 'CUSTOM', 'pattern': 'np.stack', 'id': 'np.stack'},
#  {'label': 'CUSTOM', 'pattern': 'keras.io', 'id': 'keras.io'},
#  {'label': 'CUSTOM', 'pattern': 'MeanSquaredError', 'id': 'meansquarederror'},
#  {'label': 'CUSTOM', 'pattern': 'np', 'id': 'np'},
#  {'label': 'CUSTOM', 'pattern': 'y_t', 'id': 'y_t'},
#  {'label': 'CUSTOM', 'pattern': 'np.array([[1', 'id': 'np.array-1'},
#  {'label': 'CUSTOM', 'pattern': 'loss1', 'id': 'loss1'},
#  {'label': 'CUSTOM', 'pattern': 'Tensor(621', 'id': 'tensor-621'},
#  {'label': 'CUSTOM', 'pattern': 'shape=', 'id': 'shape='},
#  {'label': 'CUSTOM', 'pattern': 'dtype=', 'id': 'dtype='},
#  {'label': 'CUSTOM', 'pattern': 'np import keras', 'id': 'np-import-keras'},
#  {'label': 'CUSTOM', 'pattern': 'mse2(y_t', 'id': 'mse2-y_t'},
#  {'label': 'CUSTOM', 'pattern': 'fns', 'id': 'fns'},
#  {'label': 'CUSTOM', 'pattern': 'EBook', 'id': 'ebook'},
#  {'label': 'CUSTOM', 'pattern': 'All Rights Reserved', 'id': 'right-reserved'},
#  {'label': 'CUSTOM', 'pattern': 'PO Box 206', 'id': 'po-box-206'},
#  {'label': 'CUSTOM', 'pattern': 'Australia', 'id': 'australia'},
#  {'label': 'CUSTOM', 'pattern': 'LinkedIn', 'id': 'linkedin'},
#  {'label': 'CUSTOM', 'pattern': '|\n\n ', 'id': ''},
#  {'label': 'CUSTOM', 'pattern': '| \n\n ', 'id': ''},
#  {'label': 'CUSTOM', 'pattern': '|\n\n Search', 'id': 'search'},
#  {'label': 'CUSTOM', 'pattern': 'CNN', 'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'CNNs', 'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'RNN', 'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'RNNs', 'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'LSTM', 'id': 'long-short-term-memory'},
#  {'label': 'CUSTOM', 'pattern': 'LSTMs', 'id': 'long-short-term-memory'}]

# %% [markdown]
# ## Find Keywords

# %% [markdown]
# Extract phrases using TextRank with no a priori assumptions on word relevance.

# %%
def get_word_list(sentence):
    word_list = []
    for w in sentence:
        if w.pos_ in ['ADJ', 'ADV', 'NOUN', 'PROPN', 'X'] and w.text not in word_list:
            word_list.append(w.text)
    return word_list

# %%
unique_word_set = set([])
edges = {}

for s in doc.sents:
    # tokenize the text using nltk
    word_list = get_word_list(s)
#     word_list.sort()

    for word in word_list:
        if word not in unique_word_set:
            unique_word_set.add(word)

    for pair in itertools.combinations(word_list, 2):
        if pair in edges.keys():
            edges[pair] += 1
        else:
            edges[pair] = 1

# %%
gr = nx.DiGraph()  # initialize an undirected graph
gr.add_nodes_from(unique_word_set)

for key, weight in edges.items():
    gr.add_edge(key[0], key[1], weight=weight)

# %%
len(gr.nodes)
# Out:
# 1024

# %%
calculated_page_rank = nx.pagerank(gr, weight='weight')

# %%
all_keywords = sorted(calculated_page_rank, key=calculated_page_rank.get,reverse=True)

# %%
def plot_bar(sorted_arr, scores, n=50):
    labels = []
    width = []
    for kp in sorted_arr[:n]:
        print(kp, scores[kp])
        labels.append(' '.join(kp) if isinstance(kp, tuple) or isinstance(kp, list) else kp)
        width.append(scores[kp])
        
    plt.figure(figsize=(5,10))
    plt.barh(range(len(labels), 0,-1), width=width, tick_label=labels)
    plt.show()

# %%
plot_bar(all_keywords, calculated_page_rank, n=50)
# Out:
# model 0.030794828676210508
# data 0.014292327711523072
# training 0.014105861479480682
# layer 0.010260839596153686
# function 0.009542622876374989
# output 0.008659027023654665
# input 0.008489308269289631
# loss 0.007789829609230795
# dataset 0.0076523089578843075
# network 0.007619875178673799
# models 0.006771727492824425
# deep 0.006417875889802246
# such 0.006320167833970157
# test 0.006285079547000383
# validation 0.006254844873063817
# values 0.006118796086606481
# API 0.005996230620765519
# layers 0.0059530324495418625
# tf.keras 0.005652680731178774
# learning 0.005321540780950055
# problem 0.005280759639919445
# inputs 0.005021519259068207
# - 0.0047079936368093055
# more 0.004627808006233942
# time 0.004572230333461161
# then 0.004550079589617938
# example 0.004523177967229978
# number 0.004518139578651848
# class 0.004371383254751938
# where 0.004295676147673553
# value 0.004287619141281438
# new 0.00428475621321943
# when 0.004222953458508981
# error 0.004174709724108571
# use 0.004069076967180583
# accuracy 0.003992952189112124
# e.g. 0.003991954204093626
# later 0.003938798259971653
# evaluation 0.0038626885961459186
# here 0.003778166824038344
# epoch 0.003764671257427856
# same 0.003763069308904858
# image 0.003745604384070683
# process 0.0036874473272376597
# code 0.003609751084088754
# row 0.003592371961019707
# line 0.003544350530056957
# prior 0.0035168474659086706
# project 0.00342269415246217
# tutorial 0.003344001125982313

# %%
np.sum([calculated_page_rank[kp] for kp in all_keywords])
# Out:
# 1.0

# %% [markdown]
# ## Find Phrases

# %%
textlist = [token.text for token in doc]
keywords = all_keywords[:len(all_keywords)//10]
phrase_freq = {}

# %%
def get_phrases(doc, keywords, k=2):
    # take keyphrases with multiple words into consideration as done in the
    # paper - if two words are adjacent in the text and are selected as
    # keywords, join them together
    modified_key_phrases = set([])
    # keeps track of individual keywords that have been joined to form a keyphrase
#     i = k-1
#     while i < len(textlist):
#         consecutive = tuple(textlist[i-k+1:i+1])
#         if all([word in keywords for word in consecutive]):
#             modified_key_phrases.add(consecutive)
#             if consecutive in phrase_freq.keys():
#                 phrase_freq[consecutive] += 1
#             else:
#                 phrase_freq[consecutive] = 1
#         i += 1

    i = k-1
    while i < len(doc):
        consecutive = tuple([token.text for token in doc[i-k+1:i+1]])
        if all([word in keywords for word in consecutive]):
            modified_key_phrases.add(consecutive)
            if consecutive in phrase_freq.keys():
                phrase_freq[consecutive] += 1
            else:
                phrase_freq[consecutive] = 1
        i += 1
        
    keyword_freq = {}
    for token in doc:
        if token.text in keywords:
            if token.text in keyword_freq.keys():
                keyword_freq[token.text] += 1
            else:
                keyword_freq[token.text] = 1
                
    return list(modified_key_phrases), keyword_freq

# %%
keyphrases, freq = get_phrases(doc, keywords, k=2)

# %%
keyphrases[:20]
# Out:
# [('learning', 'model'),
#  ('model', 'performance'),
#  ('network', 'models'),
#  ('%', 'validation'),
#  ('model', 'training'),
#  ('%', 'accuracy'),
#  ('layer', 'prior'),
#  ('use', 'deep'),
#  ('learning', 'process'),
#  ('classification', 'tasks'),
#  ('classification', 'dataset'),
#  ('error', 'loss'),
#  ('batch', 'size'),
#  ('first', 'image'),
#  ('how', 'batch'),
#  ('-', 'batch'),
#  ('CNN', 'models'),
#  ('model', 'evaluation'),
#  ('example', 'first'),
#  ('model', 'more')]

# %%
phrase_scores = {}
for p in keyphrases:
#     print(p)
    phrase_scores[p] = np.power(np.prod([phrase_freq[p] / freq[w] for w in p]), 1/len(p))

# %%
sorted_phrases = sorted(phrase_scores, key=phrase_scores.get, reverse=True)

# %%
plot_bar(sorted_phrases, phrase_scores, n=40)
# Out:
# ('deep', 'learning') 0.7067391665107075
# ('numerical', 'value') 0.6324555320336759
# ('neural', 'network') 0.5833333333333334
# ('batch', 'size') 0.5
# ('activation', 'function') 0.3835976370458337
# ('cross', '-') 0.3735436838188142
# ('-', 'entropy') 0.30499714066520933
# ('training', 'process') 0.30123203803835463
# ('learning', 'models') 0.29417420270727607
# ('example', 'below') 0.27472112789737807
# ('test', 'dataset') 0.27348170645824377
# ('entropy', 'loss') 0.26940795304016235
# ('separate', 'libraries') 0.2672612419124244
# ('next', 'value') 0.2581988897471611
# ('classification', 'accuracy') 0.24209101306752095
# ('training', 'dataset') 0.23693955110363693
# ('validation', 'dataset') 0.23179316248638265
# ('validation', 'datasets') 0.22360679774997896
# ('lines', 'codes') 0.22360679774997896
# ('very', 'close') 0.22360679774997896
# ('tf.keras', 'API') 0.21602468994692867
# ('line', 'plot') 0.21081851067789195
# ('accuracy', 'evaluation') 0.20965696734438366
# ('loss', 'function') 0.2066885083751224
# ('test', 'datasets') 0.20519567041703082
# ('classification', 'problem') 0.20025046972870356
# ('output', 'layer') 0.2000816826662603
# ('model.fit', 'data') 0.17213259316477408
# ('learning', 'library') 0.15724272550828775
# ('example', 'first') 0.14019303852301107
# ('when', 'training') 0.13483997249264842
# ('standard', 'deep') 0.13423121104280486
# ('learning', 'process') 0.12009611535381536
# ('Keras', 'API') 0.11952286093343936
# ('nodes', 'where') 0.11952286093343936
# ('execution', 'time') 0.11785113019775792
# ('image', 'classification') 0.11664236870396086
# ('deep', 'neural') 0.11624763874381928
# ('data', 'prior') 0.11268723396380222
# ('training', 'epoch') 0.11268723396380222

# %%
def get_top_half(sorted_list, scores):
    score_sum = sum([scores[k] for k in sorted_list])
    results = []
    s = 0
    i = 0
    while s < 0.5:
        norm_score = scores[sorted_list[i]] / score_sum
        s += norm_score
        results.append(sorted_list[i])
        i += 1
    return results

# %%
top_phrases = get_top_half(sorted_phrases, phrase_scores)

# %%
top_phrases
# Out:
# [('deep', 'learning'),
#  ('numerical', 'value'),
#  ('neural', 'network'),
#  ('batch', 'size'),
#  ('activation', 'function'),
#  ('cross', '-'),
#  ('-', 'entropy'),
#  ('training', 'process'),
#  ('learning', 'models'),
#  ('example', 'below'),
#  ('test', 'dataset'),
#  ('entropy', 'loss'),
#  ('separate', 'libraries'),
#  ('next', 'value'),
#  ('classification', 'accuracy'),
#  ('training', 'dataset'),
#  ('validation', 'dataset'),
#  ('very', 'close'),
#  ('validation', 'datasets'),
#  ('lines', 'codes'),
#  ('tf.keras', 'API'),
#  ('line', 'plot'),
#  ('accuracy', 'evaluation'),
#  ('loss', 'function')]

# %% [markdown]
# ### Add Phrases to Entity Rules

# %%
for phrase in top_phrases:
    pattern = ' '.join(phrase)
    pattern_id = get_ent_id(pattern)
    entity_patterns.append({'label':'CUSTOM', 'pattern': pattern, 'id':pattern_id})

# %%
entity_patterns
# Out:
# [{'label': 'CUSTOM', 'pattern': 'TensorFlow', 'id': 'tensorflow'},
#  {'label': 'CUSTOM', 'pattern': 'Google', 'id': 'google'},
#  {'label': 'CUSTOM', 'pattern': 'tf.keras API', 'id': 'tf.keras-api'},
#  {'label': 'CUSTOM', 'pattern': 'Keras', 'id': 'keras'},
#  {'label': 'CUSTOM', 'pattern': 'tf.keras', 'id': 'tf.keras'},
#  {'label': 'CUSTOM', 'pattern': 'tf.keras API', 'id': 'tf.keras-api'},
#  {'label': 'CUSTOM', 'pattern': 'Stephen Harlan', 'id': 'stephen-harlan'},
#  {'label': 'CUSTOM', 'pattern': 'API', 'id': 'api'},
#  {'label': 'CUSTOM', 'pattern': 'python', 'id': 'python'},
#  {'label': 'CUSTOM', 'pattern': 'algorithm', 'id': 'algorithm'},
#  {'label': 'CUSTOM', 'pattern': 'Python', 'id': 'python'},
#  {'label': 'CUSTOM', 'pattern': 'PyTorch', 'id': 'pytorch'},
#  {'label': 'CUSTOM', 'pattern': 'Theano', 'id': 'theano'},
#  {'label': 'CUSTOM', 'pattern': 'CNTK', 'id': 'cntk'},
#  {'label': 'CUSTOM', 'pattern': 'TensorFlow 2', 'id': 'tensorflow-2'},
#  {'label': 'CUSTOM', 'pattern': 'Keras API', 'id': 'keras-api'},
#  {'label': 'CUSTOM',
#   'pattern': 'Keras Project Homepage',
#   'id': 'keras-project-homepage'},
#  {'label': 'CUSTOM', 'pattern': 'Anaconda', 'id': 'anaconda'},
#  {'label': 'CUSTOM', 'pattern': 'GPU', 'id': 'gpu'},
#  {'label': 'CUSTOM', 'pattern': 'IDE', 'id': 'ides'},
#  {'label': 'CUSTOM', 'pattern': 'Sequential API', 'id': 'sequential-api'},
#  {'label': 'CUSTOM', 'pattern': 'Functional API', 'id': 'functional-api'},
#  {'label': 'CUSTOM', 'pattern': 'Adam', 'id': 'adam'},
#  {'label': 'CUSTOM', 'pattern': 'Sequential', 'id': 'sequential'},
#  {'label': 'CUSTOM', 'pattern': 'MLP', 'id': 'mlp'},
#  {'label': 'CUSTOM', 'pattern': 'Input', 'id': 'input'},
#  {'label': 'CUSTOM', 'pattern': 'Model', 'id': 'model'},
#  {'label': 'CUSTOM',
#   'pattern': 'Multilayer Perceptrons',
#   'id': 'multilayer-perceptrons'},
#  {'label': 'CUSTOM',
#   'pattern': 'Convolutional Neural Networks',
#   'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM',
#   'pattern': 'Recurrent Neural Networks',
#   'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM',
#   'pattern': 'Multilayer Perceptron',
#   'id': 'multilayer-perceptron'},
#  {'label': 'CUSTOM', 'pattern': 'Ionosphere', 'id': 'ionosphere'},
#  {'label': 'CUSTOM', 'pattern': 'Pandas', 'id': 'pandas'},
#  {'label': 'CUSTOM', 'pattern': 'LabelEncoder', 'id': 'labelencoder'},
#  {'label': 'CUSTOM', 'pattern': 'ReLU', 'id': 'relu'},
#  {'label': 'CUSTOM', 'pattern': 'Iris', 'id': 'iris'},
#  {'label': 'CUSTOM', 'pattern': 'Boston', 'id': 'boston'},
#  {'label': 'CUSTOM', 'pattern': 'RMSE', 'id': 'rmse'},
#  {'label': 'CUSTOM', 'pattern': 'MNIST', 'id': 'mnist'},
#  {'label': 'CUSTOM', 'pattern': 'CNN', 'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'RNN', 'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM',
#   'pattern': 'Long Short-Term Memory',
#   'id': 'long-short-term-memory'},
#  {'label': 'CUSTOM', 'pattern': 'MAE', 'id': 'mae'},
#  {'label': 'CUSTOM',
#   'pattern': 'Neural Network Architecture Learning',
#   'id': 'neural-network-architecture-learning'},
#  {'label': 'CUSTOM', 'pattern': 'validation_split', 'id': 'validation_split'},
#  {'label': 'CUSTOM', 'pattern': 'Matplotlib', 'id': 'matplotlib'},
#  {'label': 'CUSTOM', 'pattern': 'val_loss', 'id': 'val_loss'},
#  {'label': 'CUSTOM', 'pattern': 'H5', 'id': 'h5'},
#  {'label': 'CUSTOM', 'pattern': 'h5py', 'id': 'h5py'},
#  {'label': 'CUSTOM',
#   'pattern': 'BatchNormalization',
#   'id': 'batchnormalization'},
#  {'label': 'CUSTOM', 'pattern': 'EarlyStopping', 'id': 'earlystopping'},
#  {'label': 'CUSTOM',
#   'pattern': 'Convolutional Nets',
#   'id': 'convolutional-net'},
#  {'label': 'CUSTOM', 'pattern': 'Markus', 'id': 'markus'},
#  {'label': 'CUSTOM', 'pattern': 'Jason', 'id': 'jason'},
#  {'label': 'CUSTOM', 'pattern': 'Relu', 'id': 'relu'},
#  {'label': 'CUSTOM', 'pattern': 'Sigmoid', 'id': 'sigmoid'},
#  {'label': 'CUSTOM',
#   'pattern': 'https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/',
#   'id': 'https-//machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/'},
#  {'label': 'CUSTOM', 'pattern': 'tf.nn.', 'id': 'tf.nn'},
#  {'label': 'CUSTOM',
#   'pattern': 'MLP Binary Classification',
#   'id': 'mlp-binary-classification'},
#  {'label': 'CUSTOM', 'pattern': 'acc', 'id': 'acc'},
#  {'label': 'CUSTOM', 'pattern': 'MaxPool2D', 'id': 'maxpool2d'},
#  {'label': 'CUSTOM',
#   'pattern': 'https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D',
#   'id': 'https-//www.tensorflow.org/api_docs/python/tf/keras/layers/maxpool2d'},
#  {'label': 'CUSTOM', 'pattern': 'GAN', 'id': 'gan'},
#  {'label': 'CUSTOM', 'pattern': 'MUNIT', 'id': 'munit'},
#  {'label': 'CUSTOM', 'pattern': 'Mark Thanks', 'id': 'mark-thanks'},
#  {'label': 'CUSTOM', 'pattern': 'English', 'id': 'english'},
#  {'label': 'CUSTOM',
#   'pattern': 'Multiclassification',
#   'id': 'multiclassification'},
#  {'label': 'CUSTOM', 'pattern': 'JG Nice', 'id': 'jg-nice'},
#  {'label': 'CUSTOM', 'pattern': 'Hi Jason', 'id': 'hi-jason'},
#  {'label': 'CUSTOM', 'pattern': 'Validation', 'id': 'validation'},
#  {'label': 'CUSTOM', 'pattern': 'Objetive', 'id': 'objetive'},
#  {'label': 'CUSTOM', 'pattern': 'Conv2D', 'id': 'conv2d'},
#  {'label': 'CUSTOM',
#   'pattern': 'Data Augmentation',
#   'id': 'datum-augmentation'},
#  {'label': 'CUSTOM', 'pattern': 'reTrain', 'id': 'retrain'},
#  {'label': 'CUSTOM',
#   'pattern': 'ImageDataGenerator’',
#   'id': 'imagedatagenerator-’'},
#  {'label': 'CUSTOM', 'pattern': 'keras', 'id': 'keras'},
#  {'label': 'CUSTOM', 'pattern': 'Black/White', 'id': 'black/white'},
#  {'label': 'CUSTOM', 'pattern': 'np.stack', 'id': 'np.stack'},
#  {'label': 'CUSTOM', 'pattern': 'keras.io', 'id': 'keras.io'},
#  {'label': 'CUSTOM', 'pattern': 'MeanSquaredError', 'id': 'meansquarederror'},
#  {'label': 'CUSTOM', 'pattern': 'np', 'id': 'np'},
#  {'label': 'CUSTOM', 'pattern': 'y_t', 'id': 'y_t'},
#  {'label': 'CUSTOM', 'pattern': 'np.array([[1', 'id': 'np.array-1'},
#  {'label': 'CUSTOM', 'pattern': 'loss1', 'id': 'loss1'},
#  {'label': 'CUSTOM', 'pattern': 'Tensor(621', 'id': 'tensor-621'},
#  {'label': 'CUSTOM', 'pattern': 'shape=', 'id': 'shape='},
#  {'label': 'CUSTOM', 'pattern': 'dtype=', 'id': 'dtype='},
#  {'label': 'CUSTOM', 'pattern': 'np import keras', 'id': 'np-import-keras'},
#  {'label': 'CUSTOM', 'pattern': 'mse2(y_t', 'id': 'mse2-y_t'},
#  {'label': 'CUSTOM', 'pattern': 'fns', 'id': 'fns'},
#  {'label': 'CUSTOM', 'pattern': 'EBook', 'id': 'ebook'},
#  {'label': 'CUSTOM', 'pattern': 'All Rights Reserved', 'id': 'right-reserved'},
#  {'label': 'CUSTOM', 'pattern': 'PO Box 206', 'id': 'po-box-206'},
#  {'label': 'CUSTOM', 'pattern': 'Australia', 'id': 'australia'},
#  {'label': 'CUSTOM', 'pattern': 'LinkedIn', 'id': 'linkedin'},
#  {'label': 'CUSTOM', 'pattern': '|\n\n ', 'id': ''},
#  {'label': 'CUSTOM', 'pattern': '| \n\n ', 'id': ''},
#  {'label': 'CUSTOM', 'pattern': '|\n\n Search', 'id': 'search'},
#  {'label': 'CUSTOM', 'pattern': 'CNN', 'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'CNNs', 'id': 'convolutional-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'RNN', 'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'RNNs', 'id': 'recurrent-neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'LSTM', 'id': 'long-short-term-memory'},
#  {'label': 'CUSTOM', 'pattern': 'LSTMs', 'id': 'long-short-term-memory'},
#  {'label': 'CUSTOM', 'pattern': 'deep learning', 'id': 'deep-learning'},
#  {'label': 'CUSTOM', 'pattern': 'numerical value', 'id': 'numerical-value'},
#  {'label': 'CUSTOM', 'pattern': 'neural network', 'id': 'neural-network'},
#  {'label': 'CUSTOM', 'pattern': 'batch size', 'id': 'batch-size'},
#  {'label': 'CUSTOM',
#   'pattern': 'activation function',
#   'id': 'activation-function'},
#  {'label': 'CUSTOM', 'pattern': 'cross -', 'id': 'cross'},
#  {'label': 'CUSTOM', 'pattern': '- entropy', 'id': 'entropy'},
#  {'label': 'CUSTOM', 'pattern': 'training process', 'id': 'training-process'},
#  {'label': 'CUSTOM', 'pattern': 'learning models', 'id': 'learning-model'},
#  {'label': 'CUSTOM', 'pattern': 'example below', 'id': 'example'},
#  {'label': 'CUSTOM', 'pattern': 'test dataset', 'id': 'test-dataset'},
#  {'label': 'CUSTOM', 'pattern': 'entropy loss', 'id': 'entropy-loss'},
#  {'label': 'CUSTOM',
#   'pattern': 'separate libraries',
#   'id': 'separate-library'},
#  {'label': 'CUSTOM', 'pattern': 'next value', 'id': 'next-value'},
#  {'label': 'CUSTOM',
#   'pattern': 'classification accuracy',
#   'id': 'classification-accuracy'},
#  {'label': 'CUSTOM', 'pattern': 'training dataset', 'id': 'training-dataset'},
#  {'label': 'CUSTOM',
#   'pattern': 'validation dataset',
#   'id': 'validation-dataset'},
#  {'label': 'CUSTOM', 'pattern': 'very close', 'id': 'close'},
#  {'label': 'CUSTOM',
#   'pattern': 'validation datasets',
#   'id': 'validation-datasets'},
#  {'label': 'CUSTOM', 'pattern': 'lines codes', 'id': 'line-code'},
#  {'label': 'CUSTOM', 'pattern': 'tf.keras API', 'id': 'tf.keras-api'},
#  {'label': 'CUSTOM', 'pattern': 'line plot', 'id': 'line-plot'},
#  {'label': 'CUSTOM',
#   'pattern': 'accuracy evaluation',
#   'id': 'accuracy-evaluation'},
#  {'label': 'CUSTOM', 'pattern': 'loss function', 'id': 'loss-function'}]

# %% [markdown]
# ## Dependency TextRank

# %%
ruler = EntityRuler(nlp)
ruler.add_patterns(entity_patterns)
nlp.add_pipe(ruler, before='ner')

modified_doc = nlp(text)

# %%
# for ent in modified_doc.ents:
#     if ent.label_ not in skiplabels:
#         print(ent.text, ent.label_, ent.ent_id_)

# %%
with modified_doc.retokenize() as retokenizer:
    for ent in modified_doc.ents:
        retokenizer.merge(ent)

# %%
# displacy.render(modified_doc, style="ent")

# %%
displacy.render(modified_doc[:200], style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="28a9f365d473467e9e83030b8fd58680-0" class="displacy" width="30325" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Last</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Updated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">February 10,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">2020</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Predictive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">modeling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">deep learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">skill</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">modern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">developers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">need</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">know.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">TensorFlow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">premier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">open-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">source</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">deep learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">framework</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">developed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">maintained</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">by</tspan>
#     <tspan class="disp

# %%
unique_word_set = set([])
edges = {}

for s in modified_doc.sents:
#     unique_nouns = set([])
    noun_list = []
    for token in s:
        if token.pos_ in ['NOUN', 'PROPN', 'X']:
            if token.ent_id_ != '':
                noun = token.ent_id_
            else:
                noun = token.lemma_
#             print(token.lemma_)
            if noun not in noun_list:
                noun_list.append(noun)
    print(noun_list)
    
    unique_word_set.update(noun_list)

    for pair in itertools.combinations(noun_list, 2):
        if pair in edges.keys():
            edges[pair] += 1
        else:
            edges[pair] = 1
# Out:
# ['February 10', 'modeling', 'deep-learning', 'skill', 'developer']
# ['tensorflow', 'source', 'deep-learning', 'framework', 'google']
# ['tensorflow', 'tf.keras-api', 'simplicity', 'ease', 'use', 'keras', 'project']
# ['tf.keras', 'learning-model', 'prediction', 'line', 'code']
# ['deep-learning', 'task', 'classification', 'regression', 'modeling', 'developer', 'thing']
# ['tutorial', 'step', 'guide', 'learning-model', 'tensorflow', 'tf.keras-api']
# ['tutorial']
# ['tutorial', 'lot', 'fun']
# []
# ['example', 'tutorial', 'about 60 minutes']
# []
# ['learning', 'Models', 'tf.keras', 'Photo', 'stephen-harlan', 'right']
# ['tutorial', 'introduction', 'tf.keras', 'deep-learning', 'project']
# ['focus', 'api', 'deep-learning', 'model', 'development', 'task', 'math', 'theory']
# ['book']
# ['way', 'deep-learning', 'python']
# []
# ['theory']
# ['code', 'example', 'practice', 'project', 'need']
# ['head', 'api', 'documentation']
# ['tutorial', 'part', 'pace']
# []
# ['goal', 'end', 'result']
# ['pass']
# ['question']
# ['use', 'api', 'documentation', 'function']
# ['math']
# ['Math', 'way', 'algorithm', 'tool', 'algebra', 'probability', 'statistic']
# ['tool', 'algorithm']
# ['code', 'algorithm', 'behavior', 'input', 'output']
# ['math', 'algorithm']
# ['experiment']
# ['algorithm']
# ['limitation', 'deep-learning', 'algorithm']
# ['algorithm']
# ['algorithm', 'knowledge', 'period', 'time']
# ['Today', 'platform']
# ['python', 'programmer']
# ['syntax', 'python', 'language']
# ['language', 'function', 'call', 'assignment']
# ['b']
# ['way']
# ['developer', 'basic', 'language']
# ['detail']
# ['deep-learning', 'expert']
# ['benefit', 'limitation', 'algorithm', 'plenty', 'post', 'step', 'deep-learning', 'project', 'importance', 'model', 'skill', 'cross', 'validation']
# ['section', 'tf.keras']
# ['keras', 'source', 'deep-learning', 'library', 'python']
# ['project', 'Francois', 'Chollet']
# ['framework', 'developer', 'library']
# ['period', 'learning-model', 'library', 'tensorflow', 'theano', 'pytorch', 'tens or even hundreds', 'line', 'code', 'task']
# ['focus', 'library', 'research', 'flexibility', 'speed', 'ease', 'use']
# ['keras', 'api', 'learning-model', 'line', 'code']
# ['reason', 'keras', 'off', 'range', 'library', 'backend']
# ['computation', 'tensorflow', 'theano', 'cntk']
# ['power', 'library', 'GPUs', 'interface']
# ['google', 'version', 'tensorflow', 'deep-learning', 'library', 'tensorflow-2', 'keras-api', 'interface', 'default', 'development', 'platform']
# ['integration', 'tf.keras', 'interface', 'api', 'tensorflow']
# ['standalone', 'keras', 'source', 'project']
# ['keras-api', 'implementation', 'keras', 'tf.keras', 'python', 'idiom', 'api']
# ['tensorflow', 'module', 'keras-api', 'element', 'call', 'tf.keras', 'example', 'idiom']
# ['tensorflow', 'de', 'facto', 'backend', 'keras', 'source', 'project', 'integration', 'library', 'separate-library']
# ['standalone', 'keras', 'project', 'development', 'tf.keras', 'api']
# ['time', 'keras', 'user', 'tensorflow', 'backend', 'tf.keras']
# ['tf.keras', 'integration', 'tensorflow', 'feature', 'execution', 'distribution', 'support']
# []
# ['keras-project-homepage', 'December 2019']
# ['tensorflow', 'python']
# ['python', 'anaconda']
# ['tutorial', 'way', 'tensorflow', 'source', 'deep-learning', 'library']
# ['way', 'tensorflow', 'workstation', 'pip']
# ['example', 'command', 'line', 'installation', 'method', 'platform', 'package', 'manager', 'list', 'instruction']
# ['need', 'gpu']
# ['example', 'tutorial', 'cpu']
# ['tensorflow', 'gpu', 'tutorial']
# []
# ['tensorflow', 'library']
# ['step']
# ['tensorflow', 'error', 'step', 'example']
# ['file', 'versions.py', 'code']
# ['file', 'command', 'line', 'directory']
# ['type']
# ['output', 'tensorflow', 'version']
# ['version']
# ['output', 'comment']
# ['python', 'script', 'command', 'line']
# ['code', 'command', 'line', 'manner', 'notebook', 'ides']
# ['tf.keras', 'api', 'warning']
# ['message', 'hardware']
# ['feature', 'tensorflow', 'installation']
# ['example', 'workstation', 'fault']
# []
# ['information', 'message', 'execution', 'code']
# ['message', 'type']
# ['design', 'decision', 'tensorflow', 'team', 'message']
# ['downside', 'decision', 'beginner', 'developer', 'message', 'execution']
# ['tf.keras', 'tensorflow', 'development', 'environment', 'life', 'cycle', 'learning-model']
# ['section', 'life', 'cycle', 'deep-learning', 'model', 'tf.keras', 'api']
# ['model', 'life', 'cycle', 'knowledge', 'backbone', 'dataset', 'tf.keras-api']
# ['step', 'life', 'cycle']
# ['look', 'step', 'turn']
# ['model', 'type', 'architecture', 'network', 'topology']
# ['api', 'perspective', 'layer', 'model', 'number', 'node', 'activation-function']
# ['model', 'sequential-api', 'functional-api', 'look', 'section']
# ['model', 'loss-function', 'mean', 'error', 'cross']
# ['algorithm', 'optimization', 'procedure', 'gradient', 'descent', 'variation', 'adam']
# ['performance', 'track', 'model', 'training-process']
# ['api', 'perspective', 'function', 'model', 'configuration', 'data', 'structure', 'use']
# ['optimizer', 'string', 'class', 'sgd', 'gradient', 'descent', 'instance']
# ['list', 'optimizer']
# ['loss', 'function', 'list', 'metric', 'string', 'prediction']
# ['list', 'metric']
# ['model', 'training', 'configuration', 'number', 'epochs', 'loop', 'batch-size', 'sample', 'epoch', 'error']
# ['training', 'optimization', 'algorithm', 'loss-function', 'model', 'backpropagation', 'error']
# ['model', 'part', 'process', 'seconds to hours', 'day', 'complexity', 'hardware', 'size']
# ['api', 'perspective', 'function', 'training-process']
# ['function', 'training-process']
# ['help', 'batch-size', 'tutorial']
# ['model', 'progress', 'bar', 'status', 'epoch', 'training-process']
# ['report', 'model', 'performance', 'epoch', 'verbose', 'argument']
# ['output', 'training', 'verbose']
# ['model', 'holdout', 'dataset']
# ['datum', 'training-process', 'estimate', 'performance', 'model', 'prediction']
# ['speed', 'model', 'evaluation', 'amount', 'datum', 'training']
# ['api', 'perspective', 'function', 'holdout', 'loss', 'metric']
# ['prediction', 'step', 'life', 'cycle']
# ['model', 'place']
# ['datum', 'prediction', 'target', 'value']
# ['api', 'perspective', 'function', 'prediction', 'class', 'label', 'probability', 'numerical-value', 'model']
# ['model', 'prediction']
# ['model', 'datum']
# ['model', 'life', 'cycle', 'look', 'way', 'tf.keras-api']
# ['model', 'api']
# ['class', 'layer', 'model', 'manner', 'input', 'output']
# ['example', 'sequential', 'mlp', 'model', 'input', 'layer', 'node', 'output', 'numerical-value']
# ['layer', 'network', 'input_shape', 'argument']
# ['example', 'model', 'input', 'sample', 'vector', 'number']
# ['api', 'model.add']
# ['layer']
# ['example', 'mlp', 'layer']
# ['api']
# ['output', 'layer', 'input']
# ['connection']
# ['input', 'layer', 'class', 'shape', 'sample']
# ['reference', 'input', 'layer', 'model']
# ['layer', 'input']
# ['reference', 'output', 'connection', 'layer']
# ['output', 'layer', 'manner']
# ['model', 'object', 'input', 'output', 'layer']
# ['example']
# ['model', 'design', 'input', 'path', 'vector', 'output']
# ['word', 'number']
# ['api', 'lot', 'fun']
# ['api', 'model', 'life', 'cycle']
# ['section', 'prediction', 'learning-model', 'multilayer-perceptrons', 'mlp', 'convolutional-neural-network', 'recurrent-neural-network']
# ['multilayer-perceptron', 'model', 'mlp', 'standard', 'neural-network']
# ['layer', 'node', 'output']
# ['input', 'node', 'layer']
# ['mlp', 'layer']
# ['model', 'datum', 'table', 'spreadsheet', 'column', 'variable', 'row']
# ['modeling', 'problem', 'mlp', 'classification', 'multiclass', 'regression']
# ['model', 'dataset', 'case']
# ['model', 'section']
# ['performance']
# ['finding', 'comment']
# ['ionosphere', 'binary', 'class', 'classification', 'mlp']
# ['dataset', 'structure', 'atmosphere', 'radar', 'return']
# ['dataset', 'pandas']
# ['labelencoder', 'string', 'label', 'value']
# ['model', '67 percent', 'datum', 'the remaining 33 percent', 'evaluation', 'train_test_split', 'function']
# ['practice', 'activation', 'he_normal', 'weight', 'initialization']
# ['combination', 'way', 'problem', 'gradient', 'model']
# ['relu', 'tutorial', 'model', 'probability', 'class', 'activation-function']
# ['model', 'adam', 'version', 'gradient', 'descent', 'entropy-loss']
# ['example']
# ['example', 'shape', 'dataset', 'model', 'test-dataset']
# ['prediction', 'row', 'datum']
# ['result', 'nature', 'algorithm']
# ['example', 'time']
# ['result']
# ['model']
# ['finding', 'comment']
# ['case', 'model', 'classification-accuracy', 'about 94 percent', 'probability', 'row', 'datum', 'class']
# ['iris', 'flower', 'multiclass', 'classification', 'mlp']
# ['problem', 'specie', 'iris', 'flower', 'measure']
# ['dataset', 'pandas']
# ['multiclass', 'classification', 'model', 'node', 'class', 'output', 'layer', 'softmax', 'activation-function']
# ['loss-function', 'sparse_categorical_crossentropy', 'integer', 'class', 'label', 'etc']
# ['example', 'mlp', 'iris', 'flower']
# ['example', 'shape', 'dataset', 'model', 'test-dataset']
# ['prediction', 'row', 'datum']
# ['result', 'nature', 'algorithm']
# ['example', 'time']
# ['result']
# ['model']
# ['finding', 'comment']
# ['case', 'model', 'classification-accuracy', 'about 98 percent', 'probability', 'row', 'datum', 'class']
# ['boston', 'housing', 'regression', 'mlp', 'modeling']
# ['problem', 'house', 'value', 'property', 'neighborhood']
# ['dataset', 'pandas']
# ['regression', 'problem', 'numerical-value']
# ['output', 'layer', 'node', 'default', 'activation-function']
# ['error', 'mse', 'loss', 'model']
# ['regression', 'classification', 'classification-accuracy']
# ['tutorial', 'example', 'mlp', 'boston', 'housing', 'dataset']
# ['example', 'shape', 'dataset', 'model', 'test-dataset']
# ['prediction', 'row', 'datum']
# ['result', 'nature', 'algorithm']
# ['example', 'time']
# ['result']
# ['model']
# ['finding', 'comment']
# ['case', 'model', 'MSE', 'rmse']
# ['unit', 'thousands of dollars']
# ['value', 'example']
# ['convolutional-neural-network', 'type', 'network', 'image', 'input']
# ['model', 'layer']
# ['extract', 'feature', 'map', 'layer']
# ['distill', 'element']
# ['convolutional-neural-network', 'image', 'classification', 'task', 'array', 'input']
# ['image', 'classification', 'task', 'mnist', 'digit']
# ['tens of thousands', 'digit', 'number']
# ['tf.keras-api', 'convenience', 'function', 'dataset']
# ['example', 'dataset', 'image']
# ['example', 'mnist', 'dataset', 'default', 'train', 'test']
# ['plot', 'grid', 'example', 'image', 'training-dataset']
# ['Plot', 'Handwritten', 'Digits', 'mnist', 'dataset', 'convolutional-neural-network', 'model', 'image']
# ['image', 'array', 'grayscale', 'pixel', 'data', 'channel', 'dimension', 'datum', 'input', 'model']
# ['reason', 'convolutional-neural-network', 'model', 'image', 'channel', 'format', 'example', 'network', 'dimension', 'row', 'column', 'color', 'datum']
# ['idea', 'pixel', 'value', 'default', 'range', 'convolutional-neural-network']
# ['pixel', 'value', 'tutorial', 'example', 'convolutional-neural-network', 'model', 'mnist', 'dataset']
# ['example', 'shape', 'dataset', 'model', 'test-dataset']
# ['prediction', 'image']
# ['result', 'nature', 'algorithm']
# ['example', 'time']
# ['result']
# ['model']
# ['finding', 'comment']
# ['shape', 'image', 'number', 'class', 'pixel']
# ['case', 'model', 'classification-accuracy', 'about 98 percent', 'test-dataset']
# ['model', 'class', 'image', 'training']
# ['recurrent-neural-network', 'sequence', 'datum']
# ['language', 'processing', 'problem', 'sequence', 'text', 'input', 'model']
# ['recurrent-neural-network', 'success', 'time', 'series', 'forecasting', 'speech', 'recognition']
# ['type', 'recurrent-neural-network', 'long-short-term-memory', 'network']
# ['long-short-term-memory', 'model', 'sequence', 'input', 'datum', 'prediction', 'class', 'label', 'numerical-value', 'next-value', 'value']
# ['car', 'sale', 'long-short-term-memory', 'recurrent-neural-network', 'time', 'series', 'forecasting']
# ['problem', 'number', 'car', 'sale', 'month']
# ['dataset', 'pandas']
# ['problem', 'window', 'the last five months', 'datum', 'the current month']
# ['datum']
# ['function', 'split_sequence', 'input', 'sequence', 'window', 'datum', 'learning', 'model', 'long-short-term-memory']
# ['example', 'sequence', 'sample', 'model', 'the last 12 months', 'datum']
# ['long-short-term-memory', 'sample', 'dataset', 'dimension', 'number', 'time', 'step', 'case', 'observation']
# ['case']
# ['regression', 'type', 'problem', 'activation-function', 'activation', 'function', 'output', 'layer', 'mean', 'squared', 'error', 'loss-function']
# ['model', 'mean', 'error', 'mae', 'metric']
# ['example', 'long-short-term-memory', 'time', 'series', 'forecasting', 'problem']
# ['example', 'shape', 'dataset', 'model', 'test-dataset']
# ['prediction', 'example']
# ['result', 'nature', 'algorithm']
# ['example', 'time']
# ['result']
# ['model']
# ['finding', 'comment']
# ['shape', 'train', 'test', 'dataset', 'example', 'model', 'evaluation']
# ['case', 'model', 'mae', 'next-value', 'sequence', 'test', 'value']
# []
# ['practice', 'series', 'stationary', 'datum', 'model']
# ['extension', 'order', 'performance']
# ['time', 'series', 'datum', 'modeling', 'tutorial', 'section', 'model', 'feature', 'learning', 'curve', 'use']
# ['architecture', 'learning-model']
# ['idea', 'connection', 'datum', 'flow', 'model']
# ['api', 'layer', 'model', 'way']
# ['tool', 'model', 'text', 'description', 'plot']
# ['text', 'description', 'model', 'summary', 'function']
# ['example', 'model', 'layer', 'structure']
# ['example', 'print', 'summary', 'layer']
# ['diagnostic', 'output', 'shape', 'number', 'parameter', 'weight', 'model']
# ['plot', 'model', 'plot_model', 'function']
# ['image', 'file', 'box', 'line', 'diagram', 'layer', 'model']
# ['example', 'layer', 'model', 'plot', 'architecture', 'model.png', 'input', 'output', 'shape']
# ['example', 'plot', 'model', 'box', 'layer', 'shape', 'information', 'arrow', 'flow', 'datum', 'network']
# ['Plot', 'neural-network-architecture-learning', 'curve', 'plot', 'neural-network', 'model', 'performance', 'time', 'end', 'training', 'epoch']
# ['plot', 'learning', 'curve', 'insight', 'dynamic', 'model', 'training-dataset']
# ['introduction', 'learning', 'curve', 'dynamic', 'model', 'tutorial', 'learning-model']
# ['call', 'function', 'reference', 'validation-dataset']
# ['portion', 'training', 'model', 'performance']
# ['data', 'validation_data', 'argument', 'validation_split', 'percentage', 'split', 'api']
# []
# ['function', 'history', 'object', 'trace', 'performance', 'metric', 'end', 'training', 'epoch']
# ['loss-function', 'accuracy', 'loss', 'metric', 'training', 'validation-datasets']
# ['curve', 'plot', 'loss', 'training-dataset', 'validation-dataset']
# ['plot', 'history']
# ['object', 'matplotlib', 'library']
# ['example', 'neural-network', 'classification', 'problem']
# ['validation', 'split', '30 percent', 'model', 'training', 'entropy-loss', 'train', 'validation-datasets', 'line-plot']
# ['example', 'model', 'dataset']
# ['end', 'run', 'history', 'object', 'basis', 'line-plot']
# ['entropy-loss', 'loss', 'key', 'validation-dataset', 'val_loss', 'history', 'attribute', 'object']
# ['Learning', 'Curves', 'Cross', '-', 'Entropy', 'Loss', 'Deep', 'model', 'Training', 'time']
# ['model', 'prediction']
# ['save', 'function', 'model']
# ['load_model', 'function']
# ['model', 'h5', 'format', 'array', 'storage']
# ['h5py', 'library', 'workstation']
# ['pip', 'example', 'model', 'classification', 'problem', 'file']
# ['example', 'model', 'name', 'model.h5']
# ['model', 'prediction']
# ['example', 'model', 'prediction']
# ['example', 'image', 'file', 'prediction', 'row', 'datum', 'print', 'result']
# ['section', 'technique', 'performance', 'learning-model']
# ['part', 'deep-learning', 'performance', 'learning', 'process', 'time']
# ['dropout', 'regularization', 'method', 'model']
# ['training', 'number', 'layer', 'output']
# ['effect', 'layer', 'number', 'node', 'connectivity']
# ['dropout', 'effect', 'training-process', 'node', 'layer', 'responsibility', 'input']
# ['dropout', 'work', 'tutorial', 'model', 'layer', 'input', 'connection']
# ['layer', 'dropout']
# ['argument', 'probability', 'output']
# ['E.g.', '40 percent', 'input', 'update', 'model']
# ['layer', 'mlp', 'convolutional-neural-network', 'recurrent-neural-network', 'model', 'version', 'dropout', 'use']
# ['example', 'model', 'classification', 'problem']
# ['dropout', 'layer', '50 percent', 'output']
# ['scale', 'distribution', 'input', 'layer']
# ['idea', 'input', 'datum', 'model']
# ['normalization', 'technique', 'network', 'input', 'layer', '-']
# ['effect', 'learning', 'process', 'number', 'epochs', 'network']
# ['normalization', 'work', 'tutorial', 'network', 'layer', 'input']
# ['normalization', 'mlp', 'convolutional-neural-network', 'recurrent-neural-network', 'model']
# ['batchnormalization', 'layer']
# ['example', 'mlp', 'network', 'classification', 'prediction', 'problem', 'normalization', 'layer', 'output']
# ['tf.keras', 'range', 'normalization', 'layer', 'network']
# ['training', 'model', 'training-dataset']
# ['case', 'model']
# ['approach', 'problem', 'stopping']
# ['loss', 'training-dataset', 'validation-dataset', 'subset', 'training', 'model']
# ['loss', 'validation', 'set', 'sign', 'training-process']
# ['stopping', 'tutorial', 'model', 'validation-dataset']
# ['validation-dataset', 'validation_data', 'argument', 'fit', 'function', 'validation_split', 'amount', 'validation']
# ['earlystopping', 'performance', 'measure', 'val_loss', 'loss', 'validation-dataset', 'number', 'epochs', 'overfitting', 'action']
# []
# ['earlystopping', 'callback', 'fit', 'function', 'callbacks', 'argument', 'list']
# ['number', 'epochs', 'training', 'model']
# ['curve', 'insight', 'dynamic', 'run', 'training']
# ['example', 'neural-network', 'classification', 'problem', 'training', 'model', 'epochs']
# ['tf.keras-api', 'number', 'callback', 'section', 'resource', 'topic']
# ['tutorial', 'step', 'guide', 'learning-model', 'tensorflow', 'tf.keras-api']
# ['question']
# ['question', 'comment']
# ['line', 'python', 'Discover', 'Ebook']
# ['end', 'project', 'topic', 'multilayer-perceptrons', 'convolutional-net', 'Recurrent', 'Neural', 'Nets']
# ['Academics']
# ['result']
# ['thank', 'blog', 'post']
# ['case', 'mlp', 'regression', 'example', 'layer', 'node', 'activation-function', 'relu', 'sigmoid']
# ['result', 'couple', 'try', 'change', 'MSE', '1078.271', 'rmse', '1306.771']
# []
# []
# ['MSE', '2511.747', 'rmse']
# ['142.649']
# []
# ['vice', 'sigmoid']
# []
# ['example']
# ['thank', 'markus']
# []
# ['finding', 'post']
# ['reason']
# ['guess', 'data']
# []
# ['answer', 'bit']
# ['model', 'scaling', 'convolutional-neural-network', 'example']
# ['model', 'activation', 'datum']
# ['relu', 'need', 'input']
# ['jason']
# ['tutorial', 'TF']
# ['discussion', 'relu', 'sigmoid', 'output', 'function', 'problem', 'gradient', 'structure', 'network', 'layer']
# ['example']
# ['network', 'people', 'project', 'these days']
# ['sigmoid', 'function']
# ['thank']
# ['example', 'https-//machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/', 'mlp', 'regression']
# ['y', '=', 'labelencoder().fit_transform(y']
# ['prediction', 'yhat', 'y']
# ['max']
# []
# ['bug']
# ['thank']
# ['Todd']
# []
# ['bug', 'example', 'keras.callback', 'import', 'earlystopping', 'tensorflow.keras.callbacks']
# ['earlystopping', 'Thanks']
# ['yo', 'seed', 'model']
# []
# []
# ['blog', 'step']
# ['1']
# ['GRUCell']
# ['LSTMCell']
# []
# []
# ['rnncelldropoutwrapper']
# ['recurrent-neural-network']
# ['suggestion']
# ['stuff']
# ['information', 'tensorflow-2']
# ['guide', 'learning-model', 'business', 'intelligence']
# ['thank']
# ['guide']
# ['thank', 'lot']
# ['question', 'mlp-binary-classification', 'problem']
# ['evaluation', 'process', 'argument', '0s', 'loss', 'accuracy']
# []
# ['print', 'command', 'test', 'loss', 'line']
# ['print(‘Test', 'loss', '%']
# ['print(‘Test', 'accuracy', '%']
# ['%', 'acc']
# ['result', 'loss', 'test']
# ['Test', 'accuracy']
# ['function']
# ['precision', 'place']
# ['end', 'epoch', 'loss', 'accuracy', 'average', 'batch', 'evaluate']
# ['end', 'run', 'estimate', 'model', 'performance', 'hold', 'dataset']
# ['blog', 'lot', 'information', 'learner']
# ['information', 'forecasting', 'recurrent-neural-network']
# []
# ['tutorial']
# ['https://machinelearningmastery.com/start-here/#deep_learning_time_serie']
# ['hi-jason', 'convolutional-neural-network', 'example', 'maxpool2d', 'MaxPooling2D']
# ['https-//www.tensorflow.org/api_docs/python/tf/keras/layers/maxpool2d', 'thank', 'jason', 'brownlee']
# ['tutorial', 'machine', 'deep-learning', 'journey', 'alot']
# ['learning-model', 'support']
# ['tutorial', 'tf.keras', 'gan', 'model', 'munit']
# ['thank', 'suggestion']
# ['Israr', 'jason']
# ['tutorial', 'gpu', 'keras']
# ['gpu', 'number', 'backend', 'version']
# ['thank', 'mark-thanks']
# ['thank', 'post']
# ['model', 'api', 'section', 'input', 'path']
# ['question']
# ['output', 'mlp', 'model', 'image', 'datum', 'input', 'midstream', 'network']
# ['result', 'part', 'model', 'processing']
# ['model.add(intermediate_result']
# ['thank']
# ['output', 'element']
# ['layer', 'output']
# []
# ['https://machinelearningmastery.com/keras-functional-api-deep-learning/', 'api']
# []
# ['blog']
# ['emotion']
# ['donation']
# ['blog']
# ['jason', 'initiative', 'job']
# ['thank']
# ['input_shape', 'parameter', 'layer']
# ['list', 'tuple']
# ['input_shape=[8']
# []
# []
# ['question']
# ['work']
# ['layer', 'type', 'input_shape', 'parameter']
# ['thank']
# []
# []
# []
# ['https://github.com/keras-team/keras/blob/master/keras/engine/base_layer.py#l163']
# ['list', 'object', 'return', 'value', 'tuple(kwargs[‘input_shape']
# ['>', 'tuple((2']
# []
# ['>']
# ['>']
# ['>', 'tuple([2']
# []
# ['thank']
# ['Identical']
# []
# ['Thanks', 'reply']
# []
# ['Sorry', 'english', 'bit']
# ['equilivient']
# ['thing']
# ['hi-jason', 'ionosphere', 'datum', 'code', 'block', 'line']
# []
# []
# ['model.predict(([row']
# ['yhat']
# ['model.predict([row']
# ['input_shape', 'element', 'tuple']
# ['model', 'input', 'row', 'col', 'sample', 'feature']
# []
# ['tutorial']
# ['summary', 'mlp', 'convolutional-neural-network', 'recurrent-neural-network', 'model', 'dataset', 'case', 'line-code']
# ['congratulation']
# []
# ['result', 'time', 'ionosphere', 'iris', 'data', 'case', 'one']
# ['fist', 'ionosphere', 'study', 'Case', 'mlp', 'model', 'Binary Classification']
# ['difference', 'code', '80%', 'training', 'datum', '10%', 'validation', 'model.fit', 'test', 'accuracy-evaluation']
# ['batchnormalization', 'dropout']
# ['layer', 'regularization', 'purpose']
# ['unit', 'layer']
# ['97.2%', 'accuracy', 'test', '97.3%', 'class', 'good', 'example', 'iris', 'study', 'Case', 'mlp', 'multiclassification', 'difference', 'code', '80%', 'training', 'datum', '10%', 'validation', 'model.fit', 'accuracy-evaluation']
# ['batchnormalization', 'dropout']
# ['layer', 'regularization', 'purpose']
# ['unit', 'layer']
# []
# ['accuracy', 'test', '99.9%', 'class', 'iris', 'setosa', 'example']
# ['doubt', 'case', '2.1', 'applyng', 'tf.keras', 'wrapper', 'tf']
# ['version']
# ['impact', 'change', 'library']
# ['importation', 'example', 'keras', 'keras.utils', 'plot_model', 'one', 'tf.keras', 'wrapper', 'tensorflow.keras.utils', 'import']
# ['tf.keras', 'guarantee', 'maintenance', 'google', 'tensorflow', 'team']
# []
# ['2.2']
# ['efficiency', 'improvement', 'execution', 'time', 'tf.keras', 'keras']
# []
# ['change']
# []
# ['2.3']
# ['loss', 'parameter', 'multiclassification']
# ['iris', 'study', 'case', 'tutorial', 'categorical_crossentropy', 'sparse_categorical_crossentroypy']
# ['one']
# []
# ['tutorial']
# ['rest', 'study', 'case', 'tutorial']
# ['jg-nice', 'work', 'test', 'val', 'set']
# ['cross', 'validation']
# ['tf.keras']
# []
# ['efficiency', 'difference']
# []
# ['thing', 'loss']
# ['encode']
# ['thank', 'suggestion']
# ['tutorial']
# ['thank']
# ['hi-jason', 'time', 'model', 'mnist', 'Images', 'Digits', 'Multiclass']
# ['comment', 'Test', 'image', 'validation', 'training', 'test', 'model.evaluate']
# []
# []
# ['model', 'architecture']
# ['98.3%', 'accuracy']
# ['filter', 'conv2d', 'layer']
# ['98.2%', 'the 2 minutes', 'cpu', 'time', '45 minutes']
# ['2']
# ['model', 'block', 'number', 'filter', '16,32,64,128', 'conv2d`', 'batchnormalization+MaxPoool2D+', 'Dropout', 'layer', 'regularizer']
# ['result', '97.2%', '97.4%', 'batch-size']
# ['3']
# ['datum-augmentation', 'model', 'image', 'distortion', 'resolution', '96.7%', '97.3%', '97.9%', 'adn', 'height_shiftrange', '_', 'value']
# []
# ['retrain', 'epochs', 'epochs9', '98.2%', 'accuracy', 'model']
# ['tensorflow.kera', 'method', 'model.fit', 'ImageDataGenerator’']
# ['model.fit_genetator', 'keras', 'iterator']
# ['4']
# ['transfer', 'learning', 'VGG16']
# ['pixel', 'image', 'VGG16', 'requirement', 'zero', 'rest', 'row', 'column']
# ['channel', 'VGG16', 'requirement', 'image', 'time']
# ['np.stack', 'axis']
# ['result', '95.2%', 'accuracy', 'vgg16', 'block', 'head', 'layer', 'trainable']
# ['4.2']
# ['epochs', 'etc']
# ['accuracy', 'result', '96.2%', '96.7%']
# ['block', '5º', 'VGG16']
# ['epoch', '97.2%']
# ['2 minutes', 'cpu', 'time', '45 minutes', 'k', 'weight', 'M', 'trainable']
# ['block', 'number', '4th']
# ['block']
# ['CPU', 'parameter']
# ['M', 'trainable', 'parameter']
# ['98.4 %', 'Accuracy']
# ['retrain', 'VGG16', 'block']
# ['epochs', '99.4%', 'adam', 'optimizer', 'SGD', 'tuning']
# ['cost', 'cpu', 'time']
# ['conclusion', 'a']
# ['model', 'complexity', 'data_augmentation']
# ['b']
# []
# ['99.4%', 'cost', 'fo', 'VGG16', 'transfer', 'learning', '4th', 'block']
# ['cost', 'complexity', 'cpu', 'time']
# ['c']
# ['model', 'sensitive', 'epochs', 'system']
# ['regard', 'JG', 'experiment', 'learning']
# ['thank', 'finding']
# ['instance', 'datum']
# ['model.predict([row']
# ['prediction', 'test-dataset']
# ['row', 'predict', 'prediction']
# ['https://machinelearningmastery.com/how-to-make-classification-and-regression-predictions-for-deep-learning-models-in-keras/']
# ['hi-jason', 'topic']
# ['problem', 'help']
# ['suggestion', 'keras.io', 'topic', 'tf.keras', 'keras', 'model']
# ['custom', 'loss-function', 'model']
# ['look', 'tf.keras', 'keras', 'define', 'code']
# ['loss-function', 'custom', 'loss', 'fn']
# ['meansquarederror', 'observation', 'result']
# ['case', '=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['import', 'numpy', 'np', 'tensorflow', 'tf', 'y_t', 'np.array-1']
# []
# []
# ['np.array([[4']
# ['mse']
# ['meansquarederror']
# ['loss1', 'mse(y_t', 'y_p', 'print']
# ['print(‘tf.keras.losse', 'loss1']
# ['result']
# []
# ['tensor-621', 'shape=']
# ['dtype=', 'int32']
# ['case', '=']
# ['import', 'numpy', 'np-import-keras', 'np.array-1']
# []
# []
# ['np.array([[4']
# ['mse2', 'keras.losse']
# ['meansquarederror']
# ['loss2']
# ['mse2-y_t', 'y_p', 'print']
# ['print(‘keras.losse', 'loss2']
# []
# ['result', 'keras.losse']
# ['tf']
# ['shape=', 'dtype=', 'float32', '=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# ['=']
# []
# ['dtype=', 'int32', 'float32', 'input', 'datum']
# ['explanation', 'difference']
# ['model', 'loss', 'value', 'problem']
# ['meansquarederror']
# ['model']
# ['problem', 'loss', 'fns', 'keras.losse', 'model.compile']
# ['model', 'tf.keras']
# []
# ['keras', 'https://machinelearningmastery.com/faq/single-faq/what-is-the-difference-between-keras-and-tf-kera']
# ['conversion']
# ['thank', 'reply', 'jason']
# ['comment', 'name']
# ['email']
# []
# ['website', 'Deep', 'learning', 'python', 'ebook', 'stuff']
# ['©']
# ['Machine', 'Learning', 'Mastery', 'Pty']
# ['Ltd.']
# ['address', 'po-box-206', 'Vermont', 'Victoria', 'australia']
# ['|', 'ACN']
# ['linkedin']
# ['Twitter']
# []
# ['Facebook', '|\n\n ']
# ['Newsletter']
# []
# ['RSS', 'Privacy']
# []
# ['Disclaimer']
# ['term']
# []
# ['Contact']
# []
# ['Sitemap', 'search']

# %%
gr = nx.DiGraph()  # initialize an undirected graph
gr.add_nodes_from(unique_word_set)

for key, weight in edges.items():
    gr.add_edge(key[0], key[1], weight=weight)

# %%
len(gr.nodes)
# Out:
# 677

# %%
calculated_page_rank = nx.pagerank(gr, weight='weight')

# %%
all_keywords = sorted(calculated_page_rank, key=calculated_page_rank.get,reverse=True)

# %%
plot_bar(all_keywords, calculated_page_rank, n=50)
# Out:
# model 0.036014390193332434
# datum 0.019784786331821045
# layer 0.019237461649080582
# input 0.013049889942965649
# value 0.012059514054296552
# output 0.010986877815215177
# training 0.010013612184583362
# function 0.009410064074139853
# validation 0.009253399614520895
# network 0.007961544388409311
# example 0.007709693253126266
# dataset 0.0075127194593614085
# test 0.007256729342657786
# class 0.007137817631627899
# number 0.007009456624805325
# row 0.0069947659732654864
# accuracy-evaluation 0.006869997885365261
# error 0.006832730529241907
# api 0.006772386504367343
# time 0.006688625018247503
# loss 0.006475306062741329
# prediction 0.006279302054413792
# code 0.006110405278074507
# line-plot 0.005523250537019242
# parameter 0.005499447760050809
# problem 0.0054811970085528365
# training-process 0.0054754633130146705
# tf.keras 0.005475148800652892
# activation-function 0.0054552755575891735
# epoch 0.005136819341906501
# model.fit 0.004859516633077004
# use 0.004754901128413721
# convolutional-neural-network 0.004632275898706362
# tensorflow 0.004601452203337566
# library 0.0044537530784284785
# keras 0.004388290850234299
# line 0.004386936261325138
# project 0.004316610789892535
# argument 0.004277168984075434
# mlp 0.004219344748470339
# learning 0.0042030571888509215
# performance 0.004178225178327404
# np.array-1 0.004150965548627014
# metric 0.004082110841056151
# node 0.0040094257656010275
# list 0.0040076444936087766
# tutorial 0.003924361456688775
# loss-function 0.003866851612634622
# numerical-value 0.0038386530830621223
# sample 0.003784760591263467
