# %% [markdown]
# # Keyterm Parsing

# %%
import itertools
import networkx as nx
import nltk
import os
import numpy as np
import json

import matplotlib.pyplot as plt
import inflect
import string

# %%
import spacy
from spacy.matcher import Matcher
from spacy.pipeline import EntityRuler
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

# %%
with open('../samples/sample5.txt', 'r', encoding='utf-8') as f:
    text = f.read().replace('\n', ' ')

# %%
with open('../lib/plural_to_singular.json', 'r') as f:
    plural_to_singular = json.load(f)

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# from textrank_spacy import extract_top_terms

# %%
# patterns = extract_top_terms(text, stopwords, plural_to_singular)

# %%
# patterns

# %%
# for pat in patterns:
#     if pat['id'] == 'neural-network':
#         print(pat)

# %% [markdown]
# ## Entity Rules

# %% [markdown]
# Acroynms are defined as uppercase words of length greater than 1.

# %%
matcher = Matcher(nlp.vocab)
# Add match ID "HelloWorld" with no callback and one pattern
pattern = [{"IS_UPPER": True}]
matcher.add("acronym", None, pattern)

doc = nlp(text)
matches = matcher(doc)
acroynm_candidates = []
acroynm_set = set([])
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    if len(span.text) > 1 and span.text not in acroynm_set:
        acroynm_candidates.append(span)
        acroynm_set.add(span.text)
#     print(match_id, string_id, start, end, span.text)

# %%
acroynm_candidates
# Out:
# [DNA, DS, B_{F, I_{DS]

# %%
def simplify(text):
    """Convert to lowercase, remove stopword, and singularize nouns"""
    tokens = nltk.word_tokenize(text.lower())
    simplified_tokens = []
    for word in tokens:
        if word not in stopwords and word not in string.punctuation:
            if word in plural_to_singular.keys():
                singular = plural_to_singular[word]
            else:
                singular = word
            simplified_tokens.append(singular)
    return simplified_tokens

def get_ent_id(text):
    return '-'.join(simplify(text))

# %%
entity_rules = []
entity_set = set([])
entity_ids = set([])
skiplabels = [ 'DATE','TIME', 'PERCENT', 'MONEY', 'QUANTITY','ORDINAL', 'CARDINAL']
i = 0
for ent in doc.ents:
    ent_id = get_ent_id(ent.text)
#     term = ent.text
    if ent.label_ not in skiplabels and ent.text not in entity_set:
        entity_rules.append((ent, ent_id))
        entity_set.add(ent.text)
        entity_ids.add(ent_id)

# %%
entity_rules
# Out:
# [(algorithm, 'algorithm'),
#  (digital, 'digital'),
#  (quantum, 'quantum'),
#  (the  physics of computation, 'physics-computation'),
#  (Hilary Putnam, 'hilary-putnam'),
#  (Peter Godfrey-Smith, 'peter-godfrey-smith'),
#  (Gualtiero Piccinini's, "gualtiero-piccinini-'s"),
#  (Jerry Fodor, 'jerry-fodor'),
#  (Gualtiero Piccinini, 'gualtiero-piccinini'),
#  (Giunti, 'giunti'),
#  (\displaystyle H=\left(F, '\\displaystyle-h=\\left-f'),
#  (\displaystyle F, '\\displaystyle-f')]

# %%
ent_id_list = list(entity_ids)
acronym_pairs = {}
acronym_rules = []

for cand in acroynm_candidates:
    cand_lower = cand.text.lower()

    for ent_id in ent_id_list:
        tokens = ent_id.split('-')
        
        if len(cand_lower) == len(tokens):
            match = all([cand_lower[i] == tokens[i][0] for i in range(len(cand_lower))])
        else:
            match = False
        
        if match:
            acronym_pairs[cand_lower] = ent_id
            acronym_pairs[cand_lower + 's'] = ent_id
            
            acronym_rules.append((cand.text, ent_id))
            acronym_rules.append((cand.text + 's', ent_id))
            break

# %%
acronym_pairs
# Out:
# {'imap': 'internet-message-access-protocol',
#  'imaps': 'internet-message-access-protocol',
#  'pop': 'post-office-protocol',
#  'pops': 'post-office-protocol'}

# %%
acronym_rules
# Out:
# [('IMAP', 'internet-message-access-protocol'),
#  ('IMAPs', 'internet-message-access-protocol'),
#  ('POP', 'post-office-protocol'),
#  ('POPs', 'post-office-protocol')]

# %%
entity_patterns = []

for chunk, ent_id in entity_rules:
    if chunk[0].text in ['the', 'The']:
        pattern = chunk[1:].text
    else:
        pattern = chunk.text
    
    if ent_id in acronym_pairs.keys():
        pattern_id = acronym_pairs[ent_id]
    else:
        pattern_id = ent_id
        
    entity_patterns.append({'label':'CUSTOM', 'pattern':pattern, 'id':pattern_id})

# %%
for pattern, ent_id in acronym_rules:
    entity_patterns.append({'label':'CUSTOM', 'pattern':pattern, 'id':ent_id})

# %%
entity_patterns
# Out:
# [{'label': 'CUSTOM',
#   'pattern': 'IMAP',
#   'id': 'internet-message-access-protocol'},
#  {'label': 'CUSTOM', 'pattern': 'TCP/IP', 'id': 'tcp/ip'},
#  {'label': 'CUSTOM', 'pattern': 'RFC', 'id': 'rfc'},
#  {'label': 'CUSTOM', 'pattern': 'SSL', 'id': 'ssl'},
#  {'label': 'CUSTOM', 'pattern': 'Gmail', 'id': 'gmail'},
#  {'label': 'CUSTOM', 'pattern': 'Outlook.com', 'id': 'outlook.com'},
#  {'label': 'CUSTOM', 'pattern': 'Yahoo', 'id': 'yahoo'},
#  {'label': 'CUSTOM',
#   'pattern': 'Internet Message Access Protocol',
#   'id': 'internet-message-access-protocol'},
#  {'label': 'CUSTOM', 'pattern': 'RFC 3501', 'id': 'rfc-3501'},
#  {'label': 'CUSTOM', 'pattern': 'POP', 'id': 'post-office-protocol'},
#  {'label': 'CUSTOM', 'pattern': 'Pegasus Mail', 'id': 'pegasus-mail'},
#  {'label': 'CUSTOM',
#   'pattern': 'Post Office Protocol',
#   'id': 'post-office-protocol'},
#  {'label': 'CUSTOM', 'pattern': 'Mark Crispin', 'id': 'mark-crispin'},
#  {'label': 'CUSTOM', 'pattern': 'Xerox   Lisp', 'id': 'xerox-lisp'},
#  {'label': 'CUSTOM',
#   'pattern': ' Interactive Mail Access Protocol',
#   'id': 'interactive-mail-access-protocol'},
#  {'label': 'CUSTOM', 'pattern': 'IESG', 'id': 'iesg'},
#  {'label': 'CUSTOM', 'pattern': 'Historic', 'id': 'historic'},
#  {'label': 'CUSTOM',
#   'pattern': 'IMAP Working Group',
#   'id': 'imap-working-group'},
#  {'label': 'CUSTOM', 'pattern': 'RFC1176', 'id': 'rfc1176'},
#  {'label': 'CUSTOM', 'pattern': 'RFC1203', 'id': 'rfc1203'},
#  {'label': 'CUSTOM', 'pattern': 'MIME', 'id': 'mime'},
#  {'label': 'CUSTOM',
#   'pattern': 'IETF IMAP Working Group',
#   'id': 'ietf-imap-working-group'},
#  {'label': 'CUSTOM', 'pattern': 'RFC1064', 'id': 'rfc1064'},
#  {'label': 'CUSTOM', 'pattern': 'Pine', 'id': 'pine'},
#  {'label': 'CUSTOM', 'pattern': '4.00', 'id': '4.00'},
#  {'label': 'CUSTOM', 'pattern': 'POP protocol', 'id': 'pop-protocol'},
#  {'label': 'CUSTOM',
#   'pattern': 'RFC3501 section 5.2',
#   'id': 'rfc3501-section-5.2'},
#  {'label': 'CUSTOM',
#   'pattern': ' IMAP4 Access Control List (ACL',
#   'id': 'imap4-access-control-list-acl'},
#  {'label': 'CUSTOM', 'pattern': 'RFC 4314', 'id': 'rfc-4314'},
#  {'label': 'CUSTOM', 'pattern': 'IMAP4', 'id': 'imap4'},
#  {'label': 'CUSTOM',
#   'pattern': 'IETF  Lemonade Profile',
#   'id': 'ietf-lemonade-profile'},
#  {'label': 'CUSTOM', 'pattern': 'URLAUTH', 'id': 'urlauth'},
#  {'label': 'CUSTOM', 'pattern': 'TLS', 'id': 'tls'},
#  {'label': 'CUSTOM', 'pattern': 'RFC 8314', 'id': 'rfc-8314'},
#  {'label': 'CUSTOM', 'pattern': 'STARTTLS', 'id': 'starttls'},
#  {'label': 'CUSTOM', 'pattern': 'MUA', 'id': 'mua'},
#  {'label': 'CUSTOM', 'pattern': 'MSA', 'id': 'msa'},
#  {'label': 'CUSTOM', 'pattern': 'MTA', 'id': 'mta'},
#  {'label': 'CUSTOM', 'pattern': ' SMTP Protocol', 'id': 'smtp-protocol'},
#  {'label': 'CUSTOM', 'pattern': '3501', 'id': '3501'},
#  {'label': 'CUSTOM',
#   'pattern': 'IMAP',
#   'id': 'internet-message-access-protocol'},
#  {'label': 'CUSTOM',
#   'pattern': 'IMAPs',
#   'id': 'internet-message-access-protocol'},
#  {'label': 'CUSTOM', 'pattern': 'POP', 'id': 'post-office-protocol'},
#  {'label': 'CUSTOM', 'pattern': 'POPs', 'id': 'post-office-protocol'}]

# %% [markdown]
# ## Find Keywords

# %% [markdown]
# Extract phrases using TextRank with no a priori assumptions on word relevance.

# %%
def get_word_list(sentence):
    word_list = []
    for w in sentence:
        if w.pos_ in ['ADJ', 'ADV', 'NOUN', 'PROPN', 'X'] and w.text not in word_list:
            word_list.append(w.text)
    return word_list

# %%
unique_word_set = set([])
edges = {}

for s in doc.sents:
    # tokenize the text using nltk
    word_list = get_word_list(s)
#     word_list.sort()

    for word in word_list:
        if word not in unique_word_set:
            unique_word_set.add(word)

    for pair in itertools.combinations(word_list, 2):
        if pair in edges.keys():
            edges[pair] += 1
        else:
            edges[pair] = 1

# %%
gr = nx.DiGraph()  # initialize an undirected graph
gr.add_nodes_from(unique_word_set)

for key, weight in edges.items():
    gr.add_edge(key[0], key[1], weight=weight)

# %%
len(gr.nodes)
# Out:
# 422

# %%
calculated_page_rank = nx.pagerank(gr, weight='weight')

# %%
all_keywords = sorted(calculated_page_rank, key=calculated_page_rank.get,reverse=True)

# %%
def plot_bar(sorted_arr, scores, n=50):
    labels = []
    width = []
    for kp in sorted_arr[:n]:
        print(kp, scores[kp])
        labels.append(' '.join(kp) if isinstance(kp, tuple) or isinstance(kp, list) else kp)
        width.append(scores[kp])
        
    plt.figure(figsize=(5,10))
    plt.barh(range(len(labels), 0,-1), width=width, tick_label=labels)
    plt.show()

# %%
plot_bar(all_keywords, calculated_page_rank, n=50)
# Out:
# mail 0.024756760219548046
# server 0.021463092489714723
# IMAP 0.018203268087256357
# messages 0.016371696225189674
# other 0.016240727171183206
# message 0.015249465177607446
# time 0.014675879863694199
# client 0.01365443952667247
# SMTP 0.012513766716462569
# content 0.011175787841139009
# such 0.011059242113623724
# backends 0.010089213433057869
# position 0.010079669817939903
# second 0.009698034608044529
# mailbox 0.009381159763133803
# clients 0.009244150474360233
# mailboxes 0.009090831525544126
# RFC 0.008573019966735054
# servers 0.00792053881433812
# folder 0.0078072848463445225
# folders 0.0077481850498299885
# protocol 0.007568502353182209
# delivery 0.007557743207133427
# information 0.0071269117095598845
# Protocol 0.007065787253817776
# user 0.006815928460686837
# non 0.006672305025804204
# - 0.006465673549987953
# multipart 0.006195588504722937
# .citation 0.006078380909675239
# side 0.005808498430728942
# IMAP2 0.005587186401095401
# output 0.005475902951835449
# Maildir 0.005455145679422446
# state 0.005337911212628116
# Thunderbird 0.005098097307411047
# IMAP2bis 0.004996282778795437
# notification 0.0049936049461861655
# multiple 0.004843228504815334
# free 0.004808899915742408
# IMAP4rev1 0.004696176035755852
# massive 0.004695154157017969
# once 0.004642054139230933
# a,.mw 0.004631972189332128
# protocols 0.0046247029788975165
# times 0.0044314022940106544
# new 0.004413607184181257
# POP 0.004393432490243281
# alt-2.svg.png");background 0.004386913716186676
# parser 0.004344075260662576

# %%
np.sum([calculated_page_rank[kp] for kp in all_keywords])
# Out:
# 0.9999999999999999

# %% [markdown]
# ## Find Phrases

# %%
textlist = [token.text for token in doc]
keywords = all_keywords[:len(all_keywords)//10]
phrase_freq = {}

# %%
def get_phrases(doc, keywords, k=2):
    # take keyphrases with multiple words into consideration as done in the
    # paper - if two words are adjacent in the text and are selected as
    # keywords, join them together
    modified_key_phrases = set([])
    # keeps track of individual keywords that have been joined to form a keyphrase
#     i = k-1
#     while i < len(textlist):
#         consecutive = tuple(textlist[i-k+1:i+1])
#         if all([word in keywords for word in consecutive]):
#             modified_key_phrases.add(consecutive)
#             if consecutive in phrase_freq.keys():
#                 phrase_freq[consecutive] += 1
#             else:
#                 phrase_freq[consecutive] = 1
#         i += 1

    i = k-1
    while i < len(doc):
        consecutive = tuple([token.text for token in doc[i-k+1:i+1]])
        if all([word in keywords for word in consecutive]):
            modified_key_phrases.add(consecutive)
            if consecutive in phrase_freq.keys():
                phrase_freq[consecutive] += 1
            else:
                phrase_freq[consecutive] = 1
        i += 1
        
    keyword_freq = {}
    for token in doc:
        if token.text in keywords:
            if token.text in keyword_freq.keys():
                keyword_freq[token.text] += 1
            else:
                keyword_freq[token.text] = 1
                
    return list(modified_key_phrases), keyword_freq

# %%
keyphrases, freq = get_phrases(doc, keywords, k=2)

# %%
keyphrases[:20]
# Out:
# [('computational', 'system'),
#  ('computing', 'system'),
#  ('dynamical', 'system'),
#  ('computational', 'setup'),
#  ('state', 'space'),
#  ('computer', 'science')]

# %%
phrase_scores = {}
for p in keyphrases:
#     print(p)
    phrase_scores[p] = np.power(np.prod([phrase_freq[p] / freq[w] for w in p]), 1/len(p))

# %%
sorted_phrases = sorted(phrase_scores, key=phrase_scores.get, reverse=True)

# %%
plot_bar(sorted_phrases, phrase_scores, n=40)
# Out:
# ('state', 'space') 0.7071067811865476
# ('computer', 'science') 0.5773502691896257
# ('dynamical', 'system') 0.3651483716701107
# ('computational', 'setup') 0.3535533905932738
# ('computing', 'system') 0.28284271247461906
# ('computational', 'system') 0.15811388300841897

# %%
def get_top_half(sorted_list, scores):
    score_sum = sum([scores[k] for k in sorted_list])
    results = []
    s = 0
    i = 0
    while s < 0.5:
        norm_score = scores[sorted_list[i]] / score_sum
        s += norm_score
        results.append(sorted_list[i])
        i += 1
    return results

# %%
top_phrases = get_top_half(sorted_phrases, phrase_scores)

# %%
top_phrases
# Out:
# [('state', 'space'), ('computer', 'science')]

# %% [markdown]
# ### Add Phrases to Entity Rules

# %%
for phrase in top_phrases:
    pattern = ' '.join(phrase)
    pattern_id = get_ent_id(pattern)
    entity_patterns.append({'label':'CUSTOM', 'pattern': pattern, 'id':pattern_id})

# %%
entity_patterns
# Out:
# [{'label': 'CUSTOM', 'pattern': 'algorithm', 'id': 'algorithm'},
#  {'label': 'CUSTOM', 'pattern': 'digital', 'id': 'digital'},
#  {'label': 'CUSTOM', 'pattern': 'quantum', 'id': 'quantum'},
#  {'label': 'CUSTOM',
#   'pattern': ' physics of computation',
#   'id': 'physics-computation'},
#  {'label': 'CUSTOM', 'pattern': 'Hilary Putnam', 'id': 'hilary-putnam'},
#  {'label': 'CUSTOM',
#   'pattern': 'Peter Godfrey-Smith',
#   'id': 'peter-godfrey-smith'},
#  {'label': 'CUSTOM',
#   'pattern': "Gualtiero Piccinini's",
#   'id': "gualtiero-piccinini-'s"},
#  {'label': 'CUSTOM', 'pattern': 'Jerry Fodor', 'id': 'jerry-fodor'},
#  {'label': 'CUSTOM',
#   'pattern': 'Gualtiero Piccinini',
#   'id': 'gualtiero-piccinini'},
#  {'label': 'CUSTOM', 'pattern': 'Giunti', 'id': 'giunti'},
#  {'label': 'CUSTOM',
#   'pattern': '\\displaystyle H=\\left(F',
#   'id': '\\displaystyle-h=\\left-f'},
#  {'label': 'CUSTOM', 'pattern': '\\displaystyle F', 'id': '\\displaystyle-f'},
#  {'label': 'CUSTOM', 'pattern': 'state space', 'id': 'state-space'},
#  {'label': 'CUSTOM', 'pattern': 'computer science', 'id': 'computer-science'}]

# %% [markdown]
# ## Dependency TextRank

# %%
ruler = EntityRuler(nlp)
ruler.add_patterns(entity_patterns)
nlp.add_pipe(ruler, before='ner')

modified_doc = nlp(text)

# %%
# for ent in modified_doc.ents:
#     if ent.label_ not in skiplabels:
#         print(ent.text, ent.label_, ent.ent_id_)

# %%
with modified_doc.retokenize() as retokenizer:
    for ent in modified_doc.ents:
        retokenizer.merge(ent)

# %%
# displacy.render(modified_doc, style="ent")

# %%
displacy.render(modified_doc[:200], style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2bd796372dd743e58b8fa2435fce250f-0" class="displacy" width="30150" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Computation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">any</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">type</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">calculation [</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">1] [</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">2]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">includes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">arithmetical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">non-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">arithmetical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">steps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">follows</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">well-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">defined</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">model,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">example</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">algorithm .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">The</tspan>
#     <tspan class="di

# %%
unique_word_set = set([])
edges = {}

for s in modified_doc.sents:
#     unique_nouns = set([])
    noun_list = []
    for token in s:
        if token.pos_ in ['NOUN', 'PROPN', 'X']:
            if token.ent_id_ != '':
                noun = token.ent_id_
            else:
                noun = token.lemma_
#             print(token.lemma_)
            if noun not in noun_list:
                noun_list.append(noun)
    print(noun_list)
    
    unique_word_set.update(noun_list)

    for pair in itertools.combinations(noun_list, 2):
        if pair in edges.keys():
            edges[pair] += 1
        else:
            edges[pair] = 1
# Out:
# ['computation', 'type', 'calculation']
# ['step', 'model', 'example', 'algorithm']
# ['study', 'computation', 'discipline', 'computer-science']
# ['computation', 'phenomenon', 'system', 'computer']
# ['example', 'system', 'computer', 'dna', 'microfluidic', 'analog', 'wetware']
# ['point', 'view', 'physics-computation', 'branch', 'physics', 'field', 'computing']
# ['point', 'view', 'pancomputationalism', 'postulate', 'physics']
# ['evolution', 'universe', 'computation']
# ['account', 'computation', 'work', 'hilary-putnam', 'other']
# ['peter-godfrey-smith', 'mapping', 'account']
# ["gualtiero-piccinini-'s", 'summary', 'account', 'system', 'computation', 'mapping', 'state', 'transition']
# ['philosopher', 'jerry-fodor', 'account', 'computation', 'restriction', 'content', 'condition']
# ['system', 'computing', 'operand', 'computation']
# ['notion', 'abstraction', 'mapping', 'account', 'pancomputationalism', 'idea']
# ['gualtiero-piccinini', 'account', 'computation', 'philosophy']
# ['computing', 'system', 'type', 'mechanism', 'design', 'computation', 'manipulation', 'vehicle', 'rule']
# ['independence', 'property', 'realizer', 'mechanism', 'input', 'output', 'realizable']
# ['independence', 'use', 'variable', 'trait', 'voltage', 'computer', 'type', 'computation', 'brain', 'quantum']
# ['rule', 'sense', 'mapping', 'input', 'output', 'state', 'computing', 'system']
# []
# ['theory', 'computation', 'diversity', 'model', 'computer']
# ['model', 'computer']
# ['giunti', 'model', 'computation', 'theory', 'system', 'time', 'state-space']
# []
# ['ch.1']
# ['system', 'object', 'part']
# ['system', 'D', 'S', 'DS', 'time', 'state-space', 'setup', 'H']
# []
# ['F', 'B', '\\displaystyle-h=\\left-f']
# ['part']
# ['F', '\\displaystyle-f', 'part', 'B', 'B_{F', 'interpretation']
# []
# ['D']
# ['S', 'H', 'I_{DS', 'system', 'D']
# ['S', 'DS', 'setup']
# ['H', '\\displaystyle']
# ['pp.179–80']

# %%
gr = nx.DiGraph()  # initialize an undirected graph
gr.add_nodes_from(unique_word_set)

for key, weight in edges.items():
    gr.add_edge(key[0], key[1], weight=weight)

# %%
len(gr.nodes)
# Out:
# 677

# %%
calculated_page_rank = nx.pagerank(gr, weight='weight')

# %%
all_keywords = sorted(calculated_page_rank, key=calculated_page_rank.get,reverse=True)

# %%
plot_bar(all_keywords, calculated_page_rank, n=50)
# Out:
# model 0.036014390193332434
# datum 0.019784786331821045
# layer 0.019237461649080582
# input 0.013049889942965649
# value 0.012059514054296552
# output 0.010986877815215177
# training 0.010013612184583362
# function 0.009410064074139853
# validation 0.009253399614520895
# network 0.007961544388409311
# example 0.007709693253126266
# dataset 0.0075127194593614085
# test 0.007256729342657786
# class 0.007137817631627899
# number 0.007009456624805325
# row 0.0069947659732654864
# accuracy-evaluation 0.006869997885365261
# error 0.006832730529241907
# api 0.006772386504367343
# time 0.006688625018247503
# loss 0.006475306062741329
# prediction 0.006279302054413792
# code 0.006110405278074507
# line-plot 0.005523250537019242
# parameter 0.005499447760050809
# problem 0.0054811970085528365
# training-process 0.0054754633130146705
# tf.keras 0.005475148800652892
# activation-function 0.0054552755575891735
# epoch 0.005136819341906501
# model.fit 0.004859516633077004
# use 0.004754901128413721
# convolutional-neural-network 0.004632275898706362
# tensorflow 0.004601452203337566
# library 0.0044537530784284785
# keras 0.004388290850234299
# line 0.004386936261325138
# project 0.004316610789892535
# argument 0.004277168984075434
# mlp 0.004219344748470339
# learning 0.0042030571888509215
# performance 0.004178225178327404
# np.array-1 0.004150965548627014
# metric 0.004082110841056151
# node 0.0040094257656010275
# list 0.0040076444936087766
# tutorial 0.003924361456688775
# loss-function 0.003866851612634622
# numerical-value 0.0038386530830621223
# sample 0.003784760591263467
